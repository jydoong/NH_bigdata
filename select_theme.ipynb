# %%
import pandas as pd
import numpy as np
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
df = pd.read_csv('/Users/parkjeonghoon/Desktop/BITamin/NH/stock_info.csv')
df
# Out:
#            isin_cd tck_iem_cd  \
# 0     US00211V1061       AACG
# 1     US00032Q1040       AADI
# 2     US02376R1023        AAL
# 3     US03823U1025       AAOI
# 4     US0003602069       AAON
# ...            ...        ...
# 2738  US4884452065       ZVRA
# 2739  US98987D1028       ZVSA
# 2740  US98985Y1082       ZYME
# 2741  US98986X1090       ZYNE
# 2742  US98986M1036       ZYXI
#
#                                           fc_sec_krl_nm  \
# 0     ATA                                           ...
# 1     Aadi Bioscience                               ...
# 2     아메리칸 에어라인스 그룹                                 ...
# 3     어플라이드 옵토일렉트로닉스                                ...
# 4     에이에이온                                         ...
# ...                                                 ...
# 2738  Zevra                                         ...
# 2739  Zyversa                                       ...
# 2740  Zymeworks                                     ...
# 2741  자이너바 파마수티컬스                                   ...
# 2742  Zynex                                         ...
#
#                                           fc_sec_eng_nm                  섹터  \
# 0     ATA CreatGlo                                  ...  Consumer Defensive
# 1     Aadi Bioscience                               ...          Healthcare
# 2     American Airline                              ...         Industrials
# 3     AOI                                           ...          Technology
# 4     AAON                                          ...         Industrials
# ...                                                 ...                 ...
# 2738  Zevra                                         ...          Healthcare
# 2739  Zyversa                                       ...          Healthcare
# 2740  Zymeworks                                     ...          Healthcare
# 2741  Zynerba Pharms                                ...          Healthcare
# 2742  Zynex                                         ...          Healthcare
#
#                                          산업군  \
# 0              Education & Training Services
# 1                              Biotechnology
# 2                                   Airlines
# 3                    Communication Equipment
# 4              Building Products & Equipment
# ...                                      ...
# 2738                           Biotechnology
# 2739                           Biotechnology
# 2740                           Biotechnology
# 2741  Drug Manufacturers—Specialty & Generic
# 2742                    Medical Distribution
#
#                                             description        발행주식수  \
# 0     ATA Creativity Global, together with its subsi...   31585900.0
# 1     Aadi Bioscience, Inc., a clinical-stage biopha...   24519900.0
# 2     American Airlines Group Inc., through its subs...  653361984.0
# 3     Applied Optoelectronics, Inc. designs, manufac...   33342500.0
# 4     AAON, Inc., together with its subsidiaries, en...   81609504.0
# ...                                                 ...          ...
# 2738  Zevra Therapeutics, Inc., a rare disease compa...   36207100.0
# 2739  ZyVersa Therapeutics, Inc., a clinical stage b...   36394200.0
# 2740  Zymeworks Inc., a clinical-stage biopharmaceut...   67826704.0
# 2741  Zynerba Pharmaceuticals, Inc. operates as a cl...   53939400.0
# 2742  Zynex, Inc., together with its subsidiaries, d...   35100000.0
#
#       종목평균거래량(10일)     종목평균거래량  ...  mrq매출액증가율   직원보유비율  유동주식중공매도비율  \
# 0           3800.0      6822.0  ...      0.065  0.00000         NaN
# 1         130880.0    131912.0  ...      0.804  0.12510      0.0387
# 2       27378180.0  24171950.0  ...      0.047  0.01303      0.1125
# 3        2753250.0   4239232.0  ...     -0.204  0.08457      0.1936
# 4         547790.0    434956.0  ...      0.360  0.17443      0.0365
# ...            ...         ...  ...        ...      ...         ...
# 2738      151370.0    153025.0  ...      5.515  0.11387      0.0685
# 2739    21279420.0   4787927.0  ...        NaN  0.54438      0.0110
# 2740      300920.0    484875.0  ...      0.287  0.04877      0.0866
# 2741      786110.0    886206.0  ...        NaN  0.06070      0.0048
# 2742      982670.0    391738.0  ...      0.223  0.43847      0.3060
#
#              매출총이익        영업현금흐름        잉여현금흐름  위험 점수      1년PER  mrq수익상승률  \
# 0              NaN           NaN           NaN    NaN        NaN       NaN
# 1    -1.878100e+07 -5.757300e+07 -3.674612e+07    8.0        NaN       NaN
# 2     1.144300e+10  4.345000e+09  1.205875e+09    7.0   3.324742     1.769
# 3     3.362700e+07 -6.804000e+06  1.881688e+07    NaN        NaN       NaN
# 4     2.375720e+08  1.228380e+08  1.345638e+07    4.0  31.464090     1.734
# ...            ...           ...           ...    ...        ...       ...
# 2738  1.011500e+07 -2.380900e+07 -1.657262e+07    NaN        NaN       NaN
# 2739           NaN -9.196134e+06 -5.211207e+06    NaN        NaN       NaN
# 2740  2.037790e+08  1.647550e+08  8.823938e+07    NaN   2.344322       NaN
# 2741           NaN -3.164196e+07 -1.878967e+07    NaN        NaN       NaN
# 2742  1.265210e+08  1.484300e+07  1.408938e+07    7.0  17.936170     0.125
#
#       yoy수익상승률
# 0          NaN
# 1          NaN
# 2        1.811
# 3          NaN
# 4        1.865
# ...        ...
# 2738       NaN
# 2739       NaN
# 2740       NaN
# 2741       NaN
# 2742     0.002
#
# [2743 rows x 55 columns]

# %%
df_na_drop = df.dropna(subset=['description'])
df_na_drop.reset_index(drop=True, inplace=True)
df_na_drop
# Out:
#            isin_cd tck_iem_cd  \
# 0     US00211V1061       AACG
# 1     US00032Q1040       AADI
# 2     US02376R1023        AAL
# 3     US03823U1025       AAOI
# 4     US0003602069       AAON
# ...            ...        ...
# 2713  US4884452065       ZVRA
# 2714  US98987D1028       ZVSA
# 2715  US98985Y1082       ZYME
# 2716  US98986X1090       ZYNE
# 2717  US98986M1036       ZYXI
#
#                                           fc_sec_krl_nm  \
# 0     ATA                                           ...
# 1     Aadi Bioscience                               ...
# 2     아메리칸 에어라인스 그룹                                 ...
# 3     어플라이드 옵토일렉트로닉스                                ...
# 4     에이에이온                                         ...
# ...                                                 ...
# 2713  Zevra                                         ...
# 2714  Zyversa                                       ...
# 2715  Zymeworks                                     ...
# 2716  자이너바 파마수티컬스                                   ...
# 2717  Zynex                                         ...
#
#                                           fc_sec_eng_nm                  섹터  \
# 0     ATA CreatGlo                                  ...  Consumer Defensive
# 1     Aadi Bioscience                               ...          Healthcare
# 2     American Airline                              ...         Industrials
# 3     AOI                                           ...          Technology
# 4     AAON                                          ...         Industrials
# ...                                                 ...                 ...
# 2713  Zevra                                         ...          Healthcare
# 2714  Zyversa                                       ...          Healthcare
# 2715  Zymeworks                                     ...          Healthcare
# 2716  Zynerba Pharms                                ...          Healthcare
# 2717  Zynex                                         ...          Healthcare
#
#                                          산업군  \
# 0              Education & Training Services
# 1                              Biotechnology
# 2                                   Airlines
# 3                    Communication Equipment
# 4              Building Products & Equipment
# ...                                      ...
# 2713                           Biotechnology
# 2714                           Biotechnology
# 2715                           Biotechnology
# 2716  Drug Manufacturers—Specialty & Generic
# 2717                    Medical Distribution
#
#                                             description        발행주식수  \
# 0     ATA Creativity Global, together with its subsi...   31585900.0
# 1     Aadi Bioscience, Inc., a clinical-stage biopha...   24519900.0
# 2     American Airlines Group Inc., through its subs...  653361984.0
# 3     Applied Optoelectronics, Inc. designs, manufac...   33342500.0
# 4     AAON, Inc., together with its subsidiaries, en...   81609504.0
# ...                                                 ...          ...
# 2713  Zevra Therapeutics, Inc., a rare disease compa...   36207100.0
# 2714  ZyVersa Therapeutics, Inc., a clinical stage b...   36394200.0
# 2715  Zymeworks Inc., a clinical-stage biopharmaceut...   67826704.0
# 2716  Zynerba Pharmaceuticals, Inc. operates as a cl...   53939400.0
# 2717  Zynex, Inc., together with its subsidiaries, d...   35100000.0
#
#       종목평균거래량(10일)     종목평균거래량  ...  mrq매출액증가율   직원보유비율  유동주식중공매도비율  \
# 0           3800.0      6822.0  ...      0.065  0.00000         NaN
# 1         130880.0    131912.0  ...      0.804  0.12510      0.0387
# 2       27378180.0  24171950.0  ...      0.047  0.01303      0.1125
# 3        2753250.0   4239232.0  ...     -0.204  0.08457      0.1936
# 4         547790.0    434956.0  ...      0.360  0.17443      0.0365
# ...            ...         ...  ...        ...      ...         ...
# 2713      151370.0    153025.0  ...      5.515  0.11387      0.0685
# 2714    21279420.0   4787927.0  ...        NaN  0.54438      0.0110
# 2715      300920.0    484875.0  ...      0.287  0.04877      0.0866
# 2716      786110.0    886206.0  ...        NaN  0.06070      0.0048
# 2717      982670.0    391738.0  ...      0.223  0.43847      0.3060
#
#              매출총이익        영업현금흐름        잉여현금흐름  위험 점수      1년PER  mrq수익상승률  \
# 0              NaN           NaN           NaN    NaN        NaN       NaN
# 1    -1.878100e+07 -5.757300e+07 -3.674612e+07    8.0        NaN       NaN
# 2     1.144300e+10  4.345000e+09  1.205875e+09    7.0   3.324742     1.769
# 3     3.362700e+07 -6.804000e+06  1.881688e+07    NaN        NaN       NaN
# 4     2.375720e+08  1.228380e+08  1.345638e+07    4.0  31.464090     1.734
# ...            ...           ...           ...    ...        ...       ...
# 2713  1.011500e+07 -2.380900e+07 -1.657262e+07    NaN        NaN       NaN
# 2714           NaN -9.196134e+06 -5.211207e+06    NaN        NaN       NaN
# 2715  2.037790e+08  1.647550e+08  8.823938e+07    NaN   2.344322       NaN
# 2716           NaN -3.164196e+07 -1.878967e+07    NaN        NaN       NaN
# 2717  1.265210e+08  1.484300e+07  1.408938e+07    7.0  17.936170     0.125
#
#       yoy수익상승률
# 0          NaN
# 1          NaN
# 2        1.811
# 3          NaN
# 4        1.865
# ...        ...
# 2713       NaN
# 2714       NaN
# 2715       NaN
# 2716       NaN
# 2717     0.002
#
# [2718 rows x 55 columns]

# %%
df_na_drop.iloc[10]['description']
# Out:
# 'ARCA biopharma, Inc., a clinical development stage biopharmaceutical company, engages in the development and commercialization of genetically targeted therapies for cardiovascular diseases. Its lead product candidate is Gencaro, a pharmacogenetically-targeted beta-adrenergic receptor antagonist that has completed Phase IIb trial for the treatment of atrial fibrillation in patients with chronic heart failure. It is also developing Recombinant Nematode Anticoagulant Protein c2 (rNAPc2) (AB201), a protein therapeutic that is in Phase IIb clinical trial for the treatment for COVID-19. ARCA biopharma, Inc. has a collaboration agreement with LabCorp to develop genetic test for GENETIC-AF clinical trial. The company was founded in 2004 and is headquartered in Westminster, Colorado.'

# %%
cp_list = df_na_drop['tck_iem_cd'].unique()
cp_list = list(cp_list)
cp_list
# Out:
# ['AACG',
#  'AADI',
#  'AAL',
#  'AAOI',
#  'AAON',
#  'AAPL',
#  'ABCB',
#  'ABCL',
#  'ABCM',
#  'ABEO',
#  'ABIO',
#  'ABNB',
#  'ABOS',
#  'ABSI',
#  'ABUS',
#  'ABVC',
#  'ACAD',
#  'ACB',
#  'ACCD',
#  'ACDC',
#  'ACER',
#  'ACET',
#  'ACGL',
#  'ACGLN',
#  'ACGLO',
#  'ACHC',
#  'ACHL',
#  'ACHV',
#  'ACIU',
#  'ACIW',
#  'ACLS',
#  'ACLX',
#  'ACMR',
#  'ACNB',
#  'ACON',
#  'ACOR',
#  'ACRS',
#  'ACRV',
#  'ACRX',
#  'ACST',
#  'ACT',
#  'ACTG',
#  'ACVA',
#  'ACXP',
#  'ADAP',
#  'ADBE',
#  'ADD',
#  'ADEA',
#  'ADES',
#  'ADI',
#  'ADIL',
#  'ADMA',
#  'ADMP',
#  'ADN',
#  'ADP',
#  'ADPT',
#  'ADSE',
#  'ADSK',
#  'ADTH',
#  'ADTN',
#  'ADTX',
#  'ADUS',
#  'ADV',
#  'ADVM',
#  'ADXN',
#  'AEHL',
#  'AEHR',
#  'AEI',
#  'AEIS',
#  'AEMD',
#  'AEP',
#  'AEY',
#  'AEYE',
#  'AEZS',
#  'AFCG',
#  'AFIB',
#  'AFMD',
#  'AFRM',
#  'AFYA',
#  'AGAE',
#  'AGBA',
#  'AGEN',
#  'AGFY',
#  'AGIL',
#  'AGIO',
#  'AGLE',
#  'AGNC',
#  'AGNCL',
#  'AGNCM',
#  'AGNCN',
#  'AGNCO',
#  'AGNCP',
#  'AGRI',
#  'AGRX',
#  'AGYS',
#  'AHCO',
#  'AHG',
#  'AIHS',
#  'AIMD',
#  'AIP',
#  'AIRG',
#  'AIRS',
#  'AKAM',
#  'AKAN',
#  'AKBA',
#  'AKLI',
#  'AKRO',
#  'AKTS',
#  'AKTX',
#  'AKU',
#  'AKYA',
#  'ALAR',
#  'ALBT',
#  'ALCO',
#  'ALDX',
#  'ALEC',
#  'ALGM',
#  'ALGN',
#  'ALGS',
#  'ALGT',
#  'ALHC',
#  'ALIM',
#  'ALKS',
#  'ALKT',
#  'ALLK',
#  'ALLO',
#  'ALLR',
#  'ALLT',
#  'ALNY',
#  'ALPN',
#  'ALPP',
#  'ALRM',
#  'ALRN',
#  'ALRS',
#  'ALT',
#  'ALTI',
#  'ALTO',
#  'ALTR',
#  'ALVO',
#  'ALVR',
#  'ALXO',
#  'ALYA',
#  'ALZN',
#  'AMAL',
#  'AMAM',
#  'AMAT',
#  'AMBA',
#  'AMCX',
#  'AMD',
#  'AMED',
#  'AMEH',
#  'AMGN',
#  'AMKR',
#  'AMLI',
#  'AMLX',
#  'AMNB',
#  'AMPG',
#  'AMPH',
#  'AMPL',
#  'AMRK',
#  'AMRN',
#  'AMSC',
#  'AMSF',
#  'AMST',
#  'AMSWA',
#  'AMTI',
#  'AMTX',
#  'AMWD',
#  'AMZN',
#  'ANAB',
#  'ANDE',
#  'ANGH',
#  'ANGI',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANNX',
#  'ANSS',
#  'ANTX',
#  'ANY',
#  'AOSL',
#  'AOUT',
#  'APA',
#  'APCX',
#  'APDN',
#  'APEI',
#  'API',
#  'APLD',
#  'APLS',
#  'APLT',
#  'APM',
#  'APOG',
#  'APP',
#  'APPF',
#  'APPN',
#  'APPS',
#  'APTO',
#  'APVO',
#  'APYX',
#  'AQB',
#  'AQMS',
#  'AQST',
#  'ARAV',
#  'ARAY',
#  'ARBE',
#  'ARBK',
#  'ARCB',
#  'ARCC',
#  'ARCE',
#  'ARCT',
#  'ARDX',
#  'AREB',
#  'AREC',
#  'ARGX',
#  'ARHS',
#  'ARKO',
#  'ARLP',
#  'AROW',
#  'ARQQ',
#  'ARQT',
#  'ARRY',
#  'ARTL',
#  'ARTNA',
#  'ARVL',
#  'ARVN',
#  'ARWR',
#  'ASLE',
#  'ASLN',
#  'ASMB',
#  'ASML',
#  'ASND',
#  'ASO',
#  'ASPI',
#  'ASRT',
#  'ASTE',
#  'ASTI',
#  'ASTL',
#  'ASTR',
#  'ASTS',
#  'ASUR',
#  'ATAI',
#  'ATAT',
#  'ATEC',
#  'ATER',
#  'ATEX',
#  'ATHA',
#  'ATHX',
#  'ATLC',
#  'ATLCP',
#  'ATLO',
#  'ATLX',
#  'ATNF',
#  'ATNI',
#  'ATOM',
#  'ATOS',
#  'ATRA',
#  'ATRC',
#  'ATRI',
#  'ATRO',
#  'ATSG',
#  'ATVI',
#  'ATXG',
#  'ATXI',
#  'ATXS',
#  'AUID',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AUTL',
#  'AUUD',
#  'AUVI',
#  'AVAH',
#  'AVAV',
#  'AVDL',
#  'AVDX',
#  'AVGO',
#  'AVGR',
#  'AVID',
#  'AVIR',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVRO',
#  'AVT',
#  'AVTA',
#  'AVTE',
#  'AVTX',
#  'AVXL',
#  'AWH',
#  'AXDX',
#  'AXGN',
#  'AXLA',
#  'AXNX',
#  'AXON',
#  'AXSM',
#  'AXTI',
#  'AY',
#  'AYRO',
#  'AYTU',
#  'AZ',
#  'AZN',
#  'AZPN',
#  'AZTA',
#  'AZYO',
#  'BACK',
#  'BAER',
#  'BAND',
#  'BANF',
#  'BANR',
#  'BANX',
#  'BASE',
#  'BATRA',
#  'BATRK',
#  'BBCP',
#  'BBGI',
#  'BBIO',
#  'BBLG',
#  'BBSI',
#  'BCAB',
#  'BCAN',
#  'BCBP',
#  'BCDA',
#  'BCEL',
#  'BCLI',
#  'BCML',
#  'BCPC',
#  'BCRX',
#  'BCTX',
#  'BCYC',
#  'BDRX',
#  'BDSX',
#  'BDTX',
#  'BEAM',
#  'BEAT',
#  'BECN',
#  'BEEM',
#  'BELFB',
#  'BFC',
#  'BFI',
#  'BFIN',
#  'BFRI',
#  'BFST',
#  'BGC',
#  'BGFV',
#  'BGNE',
#  'BGXX',
#  'BHAT',
#  'BHF',
#  'BHFAM',
#  'BHFAN',
#  'BHFAO',
#  'BHFAP',
#  'BIAF',
#  'BIDU',
#  'BIGC',
#  'BILI',
#  'BIMI',
#  'BIOC',
#  'BIOL',
#  'BIOR',
#  'BIOX',
#  'BIRD',
#  'BITF',
#  'BIVI',
#  'BJDX',
#  'BJRI',
#  'BKCC',
#  'BKNG',
#  'BKR',
#  'BKYI',
#  'BL',
#  'BLBX',
#  'BLDE',
#  'BLDP',
#  'BLFS',
#  'BLFY',
#  'BLIN',
#  'BLKB',
#  'BLNK',
#  'BLPH',
#  'BLRX',
#  'BLTE',
#  'BLUE',
#  'BLZE',
#  'BMBL',
#  'BMEA',
#  'BMRA',
#  'BMRC',
#  'BMRN',
#  'BNGO',
#  'BNMV',
#  'BNR',
#  'BNTC',
#  'BNTX',
#  'BOKF',
#  'BOLT',
#  'BON',
#  'BOOM',
#  'BOXL',
#  'BPMC',
#  'BPOP',
#  'BPRN',
#  'BPTH',
#  'BPTS',
#  'BPYPO',
#  'BPYPP',
#  'BRAG',
#  'BRKL',
#  'BRKR',
#  'BRLT',
#  'BRP',
#  'BRQS',
#  'BRSH',
#  'BRTX',
#  'BRY',
#  'BRZE',
#  'BSFC',
#  'BSGM',
#  'BSQR',
#  'BSRR',
#  'BSVN',
#  'BSY',
#  'BTAI',
#  'BTB',
#  'BTBT',
#  'BTCS',
#  'BTCY',
#  'BTMD',
#  'BTOG',
#  'BTTX',
#  'BTWN',
#  'BUSE',
#  'BVS',
#  'BVXV',
#  'BWAY',
#  'BWB',
#  'BWEN',
#  'BWMN',
#  'BWMX',
#  'BWV',
#  'BXRX',
#  'BYND',
#  'BYRN',
#  'BYSI',
#  'BZ',
#  'BZFD',
#  'BZUN',
#  'CAAS',
#  'CABA',
#  'CAC',
#  'CACC',
#  'CACO',
#  'CADL',
#  'CAKE',
#  'CALM',
#  'CAN',
#  'CAPR',
#  'CAR',
#  'CARA',
#  'CARE',
#  'CARG',
#  'CARM',
#  'CARV',
#  'CASA',
#  'CASI',
#  'CASS',
#  'CASY',
#  'CATY',
#  'CBAN',
#  'CBAT',
#  'CBIO',
#  'CBNK',
#  'CBRL',
#  'CBSH',
#  'CBUS',
#  'CCAP',
#  'CCB',
#  'CCBG',
#  'CCCC',
#  'CCCS',
#  'CCEP',
#  'CCLD',
#  'CCLDP',
#  'CCNE',
#  'CCOI',
#  'CCRN',
#  'CCSI',
#  'CD',
#  'CDIO',
#  'CDLX',
#  'CDMO',
#  'CDNS',
#  'CDW',
#  'CDXC',
#  'CDZI',
#  'CEAD',
#  'CECO',
#  'CEG',
#  'CELC',
#  'CELH',
#  'CELU',
#  'CELZ',
#  'CENN',
#  'CENT',
#  'CENTA',
#  'CENX',
#  'CERE',
#  'CERS',
#  'CERT',
#  'CEVA',
#  'CFB',
#  'CFFN',
#  'CFLT',
#  'CFMS',
#  'CFRX',
#  'CG',
#  'CGBD',
#  'CGC',
#  'CGEM',
#  'CGEN',
#  'CGNT',
#  'CGNX',
#  'CGRN',
#  'CGTX',
#  'CHCI',
#  'CHCO',
#  'CHDN',
#  'CHEK',
#  'CHK',
#  'CHKP',
#  'CHRD',
#  'CHRS',
#  'CHRW',
#  'CHSCM',
#  'CHSCP',
#  'CHTR',
#  'CHX',
#  'CIFR',
#  'CIGI',
#  'CINF',
#  'CING',
#  'CISO',
#  'CJJD',
#  'CKPT',
#  'CLAR',
#  'CLBK',
#  'CLBT',
#  'CLDX',
#  'CLEU',
#  'CLGN',
#  'CLLS',
#  'CLMT',
#  'CLNE',
#  'CLNN',
#  'CLOV',
#  'CLPS',
#  'CLPT',
#  'CLRB',
#  'CLSD',
#  'CLSK',
#  'CLVR',
#  'CMAX',
#  'CMBM',
#  'CMCO',
#  'CMCSA',
#  'CME',
#  'CMLS',
#  'CMMB',
#  'CMND',
#  'CMPO',
#  'CMPR',
#  'CMPS',
#  'CMPX',
#  'CMRA',
#  'CMRX',
#  'CMTL',
#  'CNDT',
#  'CNET',
#  'CNEY',
#  'CNOB',
#  'CNOBP',
#  'CNSL',
#  'CNSP',
#  'CNTA',
#  'CNTB',
#  'CNTG',
#  'CNTX',
#  'CNVS',
#  'CNXA',
#  'CNXC',
#  'CNXN',
#  'COCO',
#  'COCP',
#  'CODA',
#  'CODX',
#  'COEP',
#  'COFS',
#  'COGT',
#  'COHU',
#  'COIN',
#  'COKE',
#  'COLB',
#  'COLM',
#  'COMM',
#  'COMS',
#  'CONN',
#  'COOP',
#  'CORT',
#  'COSM',
#  'COST',
#  'COYA',
#  'CPLP',
#  'CPOP',
#  'CPRT',
#  'CPRX',
#  'CPSH',
#  'CPSI',
#  'CPSS',
#  'CPTN',
#  'CRAI',
#  'CRBP',
#  'CRBU',
#  'CRCT',
#  'CRDF',
#  'CRDL',
#  'CRDO',
#  'CREG',
#  'CRESY',
#  'CREX',
#  'CRGE',
#  'CRGO',
#  'CRIS',
#  'CRKN',
#  'CRMD',
#  'CRMT',
#  'CRNC',
#  'CRNT',
#  'CRNX',
#  'CRON',
#  'CROX',
#  'CRSP',
#  'CRSR',
#  'CRUS',
#  'CRVL',
#  'CRVO',
#  'CRVS',
#  'CRWD',
#  'CSCO',
#  'CSGP',
#  'CSGS',
#  'CSIQ',
#  'CSSE',
#  'CSSEP',
#  'CSTL',
#  'CSTR',
#  'CSWC',
#  'CSWI',
#  'CSX',
#  'CTAS',
#  'CTBI',
#  'CTIB',
#  'CTKB',
#  'CTLP',
#  'CTMX',
#  'CTRM',
#  'CTRN',
#  'CTSH',
#  'CTSO',
#  'CTXR',
#  'CUE',
#  'CUEN',
#  'CURI',
#  'CUTR',
#  'CVAC',
#  'CVBF',
#  'CVCO',
#  'CVGW',
#  'CVLT',
#  'CVLY',
#  'CVRX',
#  'CWBR',
#  'CWCO',
#  'CWST',
#  'CXDO',
#  'CYCC',
#  'CYCN',
#  'CYN',
#  'CYRX',
#  'CYT',
#  'CYTH',
#  'CYTO',
#  'CZFS',
#  'CZNC',
#  'CZR',
#  'DADA',
#  'DAKT',
#  'DALN',
#  'DARE',
#  'DATS',
#  'DAVE',
#  'DAWN',
#  'DBGI',
#  'DBTX',
#  'DBVT',
#  'DBX',
#  'DCBO',
#  'DCFC',
#  'DCGO',
#  'DCOM',
#  'DCOMP',
#  'DCPH',
#  'DCTH',
#  'DDOG',
#  'DENN',
#  'DERM',
#  'DFLI',
#  'DGHI',
#  'DGICA',
#  'DGII',
#  'DGLY',
#  'DH',
#  'DHC',
#  'DHIL',
#  'DIBS',
#  'DIOD',
#  'DISH',
#  'DKNG',
#  'DLO',
#  'DLPN',
#  'DLTH',
#  'DLTR',
#  'DMAC',
#  'DMLP',
#  'DMTK',
#  'DNLI',
#  'DNUT',
#  'DOCU',
#  'DOGZ',
#  'DOMH',
#  'DOMO',
#  'DOOO',
#  'DORM',
#  'DOX',
#  'DOYU',
#  'DPRO',
#  'DRCT',
#  'DRIO',
#  'DRMA',
#  'DRRX',
#  'DRS',
#  'DRTS',
#  'DRTT',
#  'DRUG',
#  'DRVN',
#  'DSGN',
#  'DSGR',
#  'DSKE',
#  'DSP',
#  'DTIL',
#  'DTSS',
#  'DTST',
#  'DUO',
#  'DUOL',
#  'DUOT',
#  'DVAX',
#  'DWAC',
#  'DXCM',
#  'DXLG',
#  'DXPE',
#  'DYAI',
#  'DYN',
#  'DYNT',
#  'DZSI',
#  'EA',
#  'EAR',
#  'EAST',
#  'EBAY',
#  'EBC',
#  'EBET',
#  'EBIX',
#  'EBON',
#  'EBTC',
#  'ECBK',
#  'ECOR',
#  'ECPG',
#  'ECX',
#  'EDAP',
#  'EDBL',
#  'EDIT',
#  'EDRY',
#  'EDSA',
#  'EDTK',
#  'EDUC',
#  'EEFT',
#  'EFSC',
#  'EFTR',
#  'EGAN',
#  'EGHT',
#  'EGIO',
#  'EGLX',
#  'EH',
#  'EHTH',
#  'EIGR',
#  'EJH',
#  'EKSO',
#  'ELBM',
#  'ELDN',
#  'ELEV',
#  'ELOX',
#  'ELVN',
#  'ELYS',
#  'EM',
#  'EMBC',
#  'EMKR',
#  'ENG',
#  'ENLV',
#  'ENPH',
#  'ENSC',
#  'ENSG',
#  'ENTA',
#  'ENTG',
#  'ENTX',
#  'ENVB',
#  'ENVX',
#  'EOLS',
#  'EOSE',
#  'EPIX',
#  'EPOW',
#  'EPSN',
#  'EQ',
#  'EQIX',
#  'EQRX',
#  'ERAS',
#  'ERIC',
#  'ERIE',
#  'ERII',
#  'ESEA',
#  'ESGR',
#  'ESGRO',
#  'ESGRP',
#  'ESLT',
#  'ESOA',
#  'ESPR',
#  'ESQ',
#  'ESSA',
#  'ESTA',
#  'ETNB',
#  'ETON',
#  'ETSY',
#  'EUDA',
#  'EVAX',
#  'EVBG',
#  'EVCM',
#  'EVER',
#  'EVGN',
#  'EVGO',
#  'EVLO',
#  'EVLV',
#  'EVO',
#  'EVOK',
#  'EVRG',
#  'EVTV',
#  'EWBC',
#  'EWCZ',
#  'EWTX',
#  'EXAI',
#  'EXAS',
#  'EXC',
#  'EXEL',
#  'EXFY',
#  'EXLS',
#  'EXPD',
#  'EXPE',
#  'EXPI',
#  'EXPO',
#  'EXTR',
#  'EYE',
#  'EYEN',
#  'EYPT',
#  'EZFL',
#  'EZGO',
#  'EZPW',
#  'FA',
#  'FAMI',
#  'FANG',
#  'FANH',
#  'FARM',
#  'FARO',
#  'FAST',
#  'FAT',
#  'FATE',
#  'FAZE',
#  'FBIO',
#  'FBIOP',
#  'FBIZ',
#  'FBMS',
#  'FBNC',
#  'FBRX',
#  'FCBC',
#  'FCEL',
#  'FCFS',
#  'FCNCA',
#  'FCNCO',
#  'FCNCP',
#  'FCUV',
#  'FDMT',
#  'FDUS',
#  'FEAM',
#  'FELE',
#  'FENC',
#  'FFBC',
#  'FFIC',
#  'FFIE',
#  'FFIN',
#  'FFIV',
#  'FGBI',
#  'FGEN',
#  'FGI',
#  'FHB',
#  'FHTX',
#  'FIBK',
#  'FIP',
#  'FISI',
#  'FITB',
#  'FITBO',
#  'FITBP',
#  'FIVE',
#  'FIVN',
#  'FIXX',
#  'FIZZ',
#  'FLEX',
#  'FLGC',
#  'FLGT',
#  'FLIC',
#  'FLJ',
#  'FLNC',
#  'FLNT',
#  'FLUX',
#  'FLWS',
#  'FLXS',
#  'FLYW',
#  'FMAO',
#  'FNCB',
#  'FNGR',
#  'FNKO',
#  'FNLC',
#  'FOCS',
#  'FOLD',
#  'FORA',
#  'FORD',
#  'FORM',
#  'FORR',
#  'FOSL',
#  'FOX',
#  'FOXA',
#  'FPAY',
#  'FREE',
#  'FREQ',
#  'FRGI',
#  'FRGT',
#  'FRHC',
#  'FRLN',
#  'FRME',
#  'FROG',
#  'FRPH',
#  'FRPT',
#  'FRSH',
#  'FRST',
#  'FRSX',
#  'FRTX',
#  'FRZA',
#  'FSBC',
#  'FSEA',
#  'FSLR',
#  'FSTR',
#  'FSV',
#  'FTAI',
#  'FTCI',
#  'FTDR',
#  'FTEK',
#  'FTFT',
#  'FTHM',
#  'FTNT',
#  'FULC',
#  'FULT',
#  'FULTP',
#  'FUSN',
#  'FUTU',
#  'FUV',
#  'FVCB',
#  'FWBI',
#  'FWONA',
#  'FWONK',
#  'FWRD',
#  'FWRG',
#  'FYBR',
#  'GABC',
#  'GAIA',
#  'GAIN',
#  ...]

# %%
# description을 바탕으로 키워드 리스트 추출
'''
theme_dic = {}
dscp_list = []
a = df.iloc[3]['description'].split('.')
for i in range(len(df_na_drop)):
    dscp_list = df_na_drop.iloc[i]['description'].split('.')
    dscp_list = dscp_list[1].split(' ')
    
    for j in range(len(dscp_list)):
        dscp_list[j] = dscp_list[j].replace(",", '')
        
        if dscp_list[j] in theme_dic.keys():
            theme_dic[dscp_list[j]] += 1
            
        else:
            theme_dic[dscp_list[j]] = 1
            
theme_dic = {k: v for k, v in sorted(theme_dic.items(), key=lambda item: item[1], reverse=True)}
stop_list = ['', 'Its', 'include', 'and', 'the', 'in', 'company', 'a', 'of', 'for', 'United', 'States', 'operates', 
             'as', 'provides', 'to', 'services', 'products', 'with', 'develops', 'its', 'that', 'on', 'subsidiaries', 
             'internationally', 'The', 'solutions', 'development', 'focuses', 'engages', 'through', 'It']
print(theme_dic)
'''
# Out:
# '\ntheme_dic = {}\ndscp_list = []\na = df.iloc[3][\'description\'].split(\'.\')\nfor i in range(len(df_na_drop)):\n    dscp_list = df_na_drop.iloc[i][\'description\'].split(\'.\')\n    dscp_list = dscp_list[1].split(\' \')\n    \n    for j in range(len(dscp_list)):\n        dscp_list[j] = dscp_list[j].replace(",", \'\')\n        \n        if dscp_list[j] in theme_dic.keys():\n            theme_dic[dscp_list[j]] += 1\n            \n        else:\n            theme_dic[dscp_list[j]] = 1\n            \ntheme_dic = {k: v for k, v in sorted(theme_dic.items(), key=lambda item: item[1], reverse=True)}\nstop_list = [\'\', \'Its\', \'include\', \'and\', \'the\', \'in\', \'company\', \'a\', \'of\', \'for\', \'United\', \'States\', \'operates\', \n             \'as\', \'provides\', \'to\', \'services\', \'products\', \'with\', \'develops\', \'its\', \'that\', \'on\', \'subsidiaries\', \n             \'internationally\', \'The\', \'solutions\', \'development\', \'focuses\', \'engages\', \'through\', \'It\']\nprint(theme_dic)\n'

# %%
# description을 바탕으로 키워드 리스트 추출 (오래 걸림) -> 명사만 추출

theme_dic = {}
dscp_list = []
a = df.iloc[3]['description'].split('.')
for i in range(len(df_na_drop)):
    sentence = df_na_drop.iloc[i]['description'].split('.')
    sentence = sentence[1]
    doc = nlp(sentence)
    nouns = [token.text for token in doc if token.pos_ == "NOUN"]
    
    for j in range(len(nouns)):
        if nouns[j] in theme_dic.keys():
            theme_dic[nouns[j]] += 1
            
        else:
            theme_dic[nouns[j]] = 1
            
theme_dic = {k: v for k, v in sorted(theme_dic.items(), key=lambda item: item[1], reverse=True)}

print(len(theme_dic))
# Out:
# 2978

# %%
filtered_dict = {key: value for key, value in theme_dic.items() if value <=14 and value >= 10}
print(filtered_dict)
# Out:
# {'fiber': 14, 'candidate': 14, 'distributes': 14, 'trials': 14, 'protein': 14, 'body': 14, 'cells': 14, 'exploration': 14, 'sports': 14, 'self': 14, 'stores': 14, 'building': 14, 'fund': 14, 'equity': 14, 'clients': 14, 'facilities': 14, 'networking': 13, 'lines': 13, 'pipeline': 13, 'immunotherapy': 13, 'protection': 13, 'metabolic': 13, 'liver': 13, 'supply': 13, 'automation': 13, 'manufacturers': 13, 'identity': 13, 'programs': 13, 'line': 13, 'casualty': 13, 'diabetes': 13, 'logistics': 13, 'experience': 13, 'wellness': 13, 'voice': 13, 'cannabis': 12, 'fuel': 12, 'immunology': 12, 'operations': 12, 'defense': 12, 'novel': 12, 'state': 12, 'games': 12, 'men': 12, 'communication': 12, 'lending': 12, 'skin': 12, 'financing': 12, 'proteins': 11, 'patient': 11, 'infections': 11, 'signal': 11, 'retailers': 11, 'transaction': 11, 'test': 11, 'activities': 11, 'plant': 11, 'prescription': 11, 'supplies': 11, 'connectivity': 11, 'institutions': 11, 'suite': 11, 'surgery': 11, 'P': 11, 'monoclonal': 11, 'inflammation': 11, 'broadband': 11, 'retail': 11, 'agencies': 11, 'lives': 11, 'community': 11, 'footwear': 11, 'safety': 11, 'segment': 11, 'office': 11, 'users': 11, 'parts': 11, 'maintenance': 11, 'electronics': 11, 'cards': 10, 'prevention': 10, 'computing': 10, 'sells': 10, 'adult': 10, 'surface': 10, 'stem': 10, 'wealth': 10, 'families': 10, 'eye': 10, 'trading': 10, 'engagement': 10, 'steel': 10, 'hotels': 10, 'need': 10, 'tissue': 10, 'acquires': 10, 'sciences': 10, 'brokerage': 10, 'meat': 10, 'networks': 10, 'loan': 10, 'machine': 10, 'consulting': 10, 'animal': 10, 'term': 10}

# %%
# 분야 리스트 작성 중이었음. (노가다 하고 있는 것.)
key_list = ['therapies', 'biotechnology', 'cancer',   'patients', 'therapeutics', 
            'cell', 'insurance', 'energy',
            'video', 'entertainment', 'semiconductor', 'cancers','transportation', 
            'infrastructure', 'trial','food', 'security', 'intelligence',
            'media', 'design', 'designs', 'molecule',
            'tumors', 'medicine' , 'air', 
            'provision', 'restaurants',
            'travel', 'water', 'fiber',
             'plant']

key_dic = {
    'retail': ['retailer', 'retailers', 'retail'],
    'mining': ['mining'],
    'oil': ['oil', 'petroleum'],
    'transport': ['transportation', 'delivery', 'transport'],
    'vehicle': ['vehicles', 'vehicle'],
    'bank': ['banking', 'bank', 'savings', 'loans', 'mortgage', 'credit'],
    'data': ['cloud', 'data'],
    'optic': ['optic-fiber', 'laser'],
    'game': ['gaming', 'games', 'game'],
    'ad': ['advertising', 'advertisement'],
    'device': ['computer', 'computers', 'software', 'hardware', 'devices', 'device'],
    'energy': ['gas', 'oil', 'fuel'],
    'materials': ['materials', 'mining', 'metal', 'steel', 'semiconductor'],
    'network': ['network', 'networks', 'internet'],
    'sport': ['sports', 'sport'],
    'water': ['water'],
    'accessory': ['accessories', 'accessory'],
    'education': ['education', 'educational'],
    'security': ['security'],
    'ai': ['intelligence', 'ai', 'a.i.', 'A.I.', 'AI'],
    'entertainment': ['entertainment'],
    'estate': ['estate'],
    'food': ['food', 'restaurants', 'meat'],
    'travel': ['travel'],
    'medicine' : ['therapies', 'cancer', 'drugs','antibody', 'gene', 'immunotherapies', 'drug', 'pharmaceutical', 'vaccine', 'vaccines'],
    'communication' : ['communication', 'communications', 'community'],
    'media' : ['video', 'videos', 'media']
    }

# %%
sentence = df_na_drop.iloc[0]['description'].split('.')
sentence = sentence[1]
doc = nlp(sentence)
nouns = [token.text for token in doc if token.pos_ == "NOUN"]
print("Extracted nouns:", nouns)
print(sentence)
# Out:
# Extracted nouns: ['services', 'portfolio', 'training', 'research', 'learning', 'study', 'counselling', 'school', 'art', 'classes', 'cooperation', 'schools', 'language', 'training', 'services', 'art', 'education', 'school', 'art', 'classes', 'art', 'education', 'services', 'students']
#  Its educational services include portfolio training, research-based learning, overseas study counselling, in-school art classes through cooperation with high schools, foreign language training services, junior art education, in-school art classes, junior art education, and other related educational services to its students

# %%
# 각 분야에 해당하는 회사 dictionary
cp_from_theme = {}

for i in range(len(df_na_drop)):
    lst = df_na_drop.iloc[i]['description']
    lst = lst.lower()
    lst = lst.replace(',', '')
    lst = lst.replace('.', '')
    lst = lst.split(" ")
    for word in key_dic.keys():
        for wrd in key_dic[word]:
            if wrd in lst:
                if word in cp_from_theme.keys():
                    cp_from_theme[word].append(df_na_drop.iloc[i]['tck_iem_cd'])
                    
                else:
                    cp_from_theme[word] = [df_na_drop.iloc[i]['tck_iem_cd']]

for k in key_dic.keys():
    cp_from_theme[k] = set(cp_from_theme[k])

cp_from_theme
# Out:
# {'network': {'AACG',
#   'AAL',
#   'AAOI',
#   'AAON',
#   'AAPL',
#   'ADBE',
#   'ADEA',
#   'ADSK',
#   'ADTN',
#   'AEIS',
#   'AEY',
#   'AEYE',
#   'AFYA',
#   'AGAE',
#   'AGBA',
#   'AKAM',
#   'ALAR',
#   'ALLT',
#   'ALRM',
#   'ALTR',
#   'ALYA',
#   'AMBA',
#   'AMCX',
#   'AMD',
#   'AMEH',
#   'AMPG',
#   'AMPL',
#   'AMRK',
#   'AMSWA',
#   'AMWD',
#   'ANY',
#   'API',
#   'APP',
#   'ARCB',
#   'ARLP',
#   'ASTS',
#   'ATEC',
#   'ATEX',
#   'ATLC',
#   'ATLCP',
#   'ATNI',
#   'AVDX',
#   'AVGO',
#   'AVNW',
#   'AXTI',
#   'BASE',
#   'BCML',
#   'BEEM',
#   'BIDU',
#   'BIOL',
#   'BKYI',
#   'BLNK',
#   'BLZE',
#   'BOKF',
#   'BRP',
#   'BSVN',
#   'BSY',
#   'BTCS',
#   'BUSE',
#   'BWMX',
#   'BYRN',
#   'BZFD',
#   'CAR',
#   'CASA',
#   'CATY',
#   'CBAN',
#   'CCCS',
#   'CCOI',
#   'CD',
#   'CDLX',
#   'CDW',
#   'CDXC',
#   'CFB',
#   'CG',
#   'CGNT',
#   'CGNX',
#   'CGRN',
#   'CHKP',
#   'CHRW',
#   'CHSCM',
#   'CHSCP',
#   'CHTR',
#   'CMBM',
#   'CMCSA',
#   'CMTL',
#   'CNET',
#   'CNOB',
#   'CNOBP',
#   'CNSL',
#   'COLM',
#   'COMM',
#   'COMS',
#   'CPRT',
#   'CPSH',
#   'CRCT',
#   'CRGE',
#   'CRNT',
#   'CRSR',
#   'CRVL',
#   'CRWD',
#   'CSCO',
#   'CSSE',
#   'CSSEP',
#   'CSX',
#   'CTAS',
#   'CTBI',
#   'CTIB',
#   'CURI',
#   'CUTR',
#   'CVCO',
#   'CVLT',
#   'CXDO',
#   'DATS',
#   'DDOG',
#   'DGII',
#   'DH',
#   'DISH',
#   'DKNG',
#   'DOX',
#   'DRRX',
#   'DRS',
#   'DRTT',
#   'DRVN',
#   'DTST',
#   'DUO',
#   'DZSI',
#   'EBON',
#   'EDUC',
#   'EEFT',
#   'EFSC',
#   'EGHT',
#   'EGIO',
#   'EPOW',
#   'ERIC',
#   'EVGO',
#   'EXTR',
#   'FARM',
#   'FBMS',
#   'FBNC',
#   'FCFS',
#   'FCNCA',
#   'FCNCO',
#   'FCNCP',
#   'FFIC',
#   'FFIN',
#   'FFIV',
#   'FLJ',
#   'FLXS',
#   'FLYW',
#   'FOX',
#   'FOXA',
#   'FSTR',
#   'FTFT',
#   'FTNT',
#   'FULT',
#   'FULTP',
#   'FYBR',
#   'GAIA',
#   'GAN',
#   'GDS',
#   'GDYN',
#   'GEOS',
#   'GFS',
#   'GGR',
#   'GILT',
#   'GMBL',
#   'GO',
#   'GOOG',
#   'GOOGL',
#   'GROM',
#   'GRRR',
#   'GT',
#   'HAYN',
#   'HCP',
#   'HIFS',
#   'HIMX',
#   'HLIT',
#   'HONE',
#   'HOPE',
#   'HSIC',
#   'HTOO',
#   'HUBC',
#   'HUIZ',
#   'HWBK',
#   'IAC',
#   'IART',
#   'IBOC',
#   'IDCC',
#   'IESC',
#   'IHRT',
#   'IIIV',
#   'IMTE',
#   'INDB',
#   'INFN',
#   'INO',
#   'INPX',
#   'INSG',
#   'INTC',
#   'INTZ',
#   'IPGP',
#   'IQ',
#   'IRDM',
#   'ISPC',
#   'ITRI',
#   'IVDA',
#   'JAMF',
#   'JBHT',
#   'JJSF',
#   'KFRC',
#   'KOSS',
#   'KPLT',
#   'KRON',
#   'KSCP',
#   'LAKE',
#   'LAUR',
#   'LBRDA',
#   'LBRDK',
#   'LBTYA',
#   'LBTYK',
#   'LEGH',
#   'LFVN',
#   'LGMK',
#   'LILA',
#   'LILAK',
#   'LKCO',
#   'LNTH',
#   'LOGI',
#   'LOV',
#   'LSCC',
#   'LVO',
#   'LWLG',
#   'LYFT',
#   'MANH',
#   'MASI',
#   'MCFT',
#   'MDGS',
#   'MF',
#   'MGRC',
#   'MIND',
#   'MINM',
#   'MKSI',
#   'MLGO',
#   'MMYT',
#   'MNDO',
#   'MNSB',
#   'MODV',
#   'MOND',
#   'MOXC',
#   'MRAM',
#   'MRVL',
#   'MSFT',
#   'MSGM',
#   'MXL',
#   'MYRG',
#   'NCMI',
#   'NCTY',
#   'NKLA',
#   'NKSH',
#   'NN',
#   'NNOX',
#   'NTAP',
#   'NTCT',
#   'NTES',
#   'NTGR',
#   'NTNX',
#   'NTRA',
#   'NUTX',
#   'NVDA',
#   'NVEC',
#   'NWFL',
#   'NWS',
#   'NWSA',
#   'NXPI',
#   'NXPL',
#   'NXST',
#   'OBLG',
#   'OCSL',
#   'ODP',
#   'OLB',
#   'ONDS',
#   'ONFO',
#   'OPRX',
#   'ORGS',
#   'OSS',
#   'OSTK',
#   'OTEX',
#   'OXSQ',
#   'PANW',
#   'PARA',
#   'PARAA',
#   'PARAP',
#   'PCAR',
#   'PCB',
#   'PCTI',
#   'PEP',
#   'PERI',
#   'PETS',
#   'PFC',
#   'PGC',
#   'PGNY',
#   'PKBK',
#   'PLPC',
#   'PLUG',
#   'PMTS',
#   'POET',
#   'POLA',
#   'POWI',
#   'PRCH',
#   'PRFT',
#   'PRGS',
#   'PRTS',
#   'PRVA',
#   'PUBM',
#   'PWOD',
#   'QDEL',
#   'QMCO',
#   'QRTEA',
#   'QRTEP',
#   'QRVO',
#   'QUIK',
#   'RBBN',
#   'RBCAA',
#   'RDWR',
#   'REAX',
#   'RELI',
#   'RFIL',
#   'ROP',
#   'RUN',
#   'RUSHA',
#   'RWAY',
#   'SABR',
#   'SALM',
#   'SANM',
#   'SATS',
#   'SBET',
#   'SBGI',
#   'SCHL',
#   'SCKT',
#   'SCOR',
#   'SCSC',
#   'SDC',
#   'SFNC',
#   'SFST',
#   'SGH',
#   'SGRY',
#   'SHBI',
#   'SIFY',
#   'SIRI',
#   'SITM',
#   'SLAB',
#   'SLGG',
#   'SLNH',
#   'SMBK',
#   'SMTC',
#   'SNCE',
#   'SNCR',
#   'SNEX',
#   'SNTG',
#   'SOPA',
#   'SPCB',
#   'SPLK',
#   'SSP',
#   'SSYS',
#   'STBX',
#   'STGW',
#   'SWVL',
#   'SY',
#   'SYTA',
#   'TAOP',
#   'TCX',
#   'TFIN',
#   'TGL',
#   'TH',
#   'THRY',
#   'TITN',
#   'TLS',
#   'TMUS',
#   'TRIB',
#   'TRUE',
#   'TSAT',
#   'TSLA',
#   'TSP',
#   'TTGT',
#   'TTMI',
#   'TUSK',
#   'TWIN',
#   'TZOO',
#   'UBSI',
#   'UCL',
#   'UEIC',
#   'UFCS',
#   'UMBF',
#   'UONE',
#   'UONEK',
#   'UPST',
#   'UPWK',
#   'USIO',
#   'VABK',
#   'VCSA',
#   'VEEE',
#   'VIAV',
#   'VIEW',
#   'VIRC',
#   'VNET',
#   'VOD',
#   'VRNS',
#   'VRSN',
#   'VSAT',
#   'WAFD',
#   'WAFDP',
#   'WASH',
#   'WBD',
#   'WDC',
#   'WWD',
#   'XGN',
#   'XNET',
#   'XP',
#   'XRX',
#   'Z',
#   'ZBRA',
#   'ZD',
#   'ZFOX',
#   'ZG',
#   'ZI',
#   'ZS'},
#  'education': {'AACG',
#   'AAON',
#   'AAPL',
#   'ACIW',
#   'ADD',
#   'AFYA',
#   'ALAR',
#   'ALBT',
#   'ALLT',
#   'ALTI',
#   'APDN',
#   'APEI',
#   'API',
#   'APOG',
#   'ARCE',
#   'AROW',
#   'AUVI',
#   'AVDX',
#   'AVT',
#   'BANF',
#   'BHAT',
#   'BKYI',
#   'BLKB',
#   'BOOM',
#   'BOXL',
#   'BSGM',
#   'CARE',
#   'CCOI',
#   'CCRN',
#   'CCSI',
#   'CDNS',
#   'CDW',
#   'CG',
#   'CHKP',
#   'CLEU',
#   'CMBM',
#   'CNXN',
#   'CPOP',
#   'CPSI',
#   'CTSH',
#   'CVLT',
#   'CZNC',
#   'DBX',
#   'DCBO',
#   'DRCT',
#   'DRTT',
#   'DSGR',
#   'DTST',
#   'EDTK',
#   'EDUC',
#   'EHTH',
#   'EPOW',
#   'ETSY',
#   'EVBG',
#   'EXAS',
#   'EXTR',
#   'FBMS',
#   'FCBC',
#   'FCEL',
#   'FIBK',
#   'FIVN',
#   'FLYW',
#   'FNLC',
#   'FRHC',
#   'FTNT',
#   'GLAD',
#   'GRNQ',
#   'GSUN',
#   'HCAT',
#   'HONE',
#   'HOOD',
#   'HSIC',
#   'HSII',
#   'HSTM',
#   'HTLF',
#   'HURN',
#   'ICFI',
#   'IESC',
#   'IFBD',
#   'IIIV',
#   'INFN',
#   'JG',
#   'JZ',
#   'KC',
#   'KELYA',
#   'KLTR',
#   'KRMD',
#   'LAUR',
#   'LBRDA',
#   'LBRDK',
#   'LINC',
#   'LPLA',
#   'MAPS',
#   'MFIC',
#   'MGRC',
#   'MKTW',
#   'MLKN',
#   'MNDY',
#   'MSTR',
#   'NAVI',
#   'NMFC',
#   'NRDS',
#   'NTCT',
#   'NTES',
#   'NTNX',
#   'NVOS',
#   'OBLG',
#   'OCSL',
#   'OST',
#   'PANW',
#   'PDCO',
#   'PFIS',
#   'PHUN',
#   'PNTG',
#   'PRDO',
#   'PSEC',
#   'PTMN',
#   'PYCR',
#   'QMCO',
#   'RBBN',
#   'RPD',
#   'RWAY',
#   'SCHL',
#   'SCKT',
#   'SCSC',
#   'SGH',
#   'SLM',
#   'SMBK',
#   'SPLK',
#   'SPT',
#   'SRCL',
#   'SSP',
#   'STER',
#   'STRA',
#   'TAOP',
#   'THRN',
#   'TIGR',
#   'TILE',
#   'TOWN',
#   'TWOU',
#   'UCBI',
#   'UCBIO',
#   'UGRO',
#   'VEDU',
#   'VIEW',
#   'VIRC',
#   'VRAR',
#   'VTRS',
#   'VTRU',
#   'VTSI',
#   'WDAY',
#   'WIMI',
#   'WSC',
#   'XMTR',
#   'XP',
#   'YQ',
#   'ZCMD',
#   'ZFOX',
#   'ZI',
#   'ZM',
#   'ZS'},
#  'medicine': {'AADI',
#   'AAON',
#   'ABCL',
#   'ABCM',
#   'ABEO',
#   'ABIO',
#   'ABOS',
#   'ABSI',
#   'ABVC',
#   'ACER',
#   'ACET',
#   'ACHL',
#   'ACHV',
#   'ACIU',
#   'ACLX',
#   'ACOR',
#   'ACRS',
#   'ACRV',
#   'ACRX',
#   'ACST',
#   'ACTG',
#   'ADAP',
#   'ADIL',
#   'ADMA',
#   'ADMP',
#   'ADPT',
#   'ADVM',
#   'ADXN',
#   'AEMD',
#   'AFMD',
#   'AGEN',
#   'AKRO',
#   'AKTX',
#   'ALDX',
#   'ALEC',
#   'ALGS',
#   'ALIM',
#   'ALKS',
#   'ALLK',
#   'ALLO',
#   'ALLR',
#   'ALPN',
#   'ALRN',
#   'ALTR',
#   'ALVO',
#   'ALVR',
#   'ALXO',
#   'ALZN',
#   'AMAM',
#   'AMED',
#   'AMGN',
#   'AMPH',
#   'AMRN',
#   'AMTI',
#   'ANAB',
#   'ANGO',
#   'ANIP',
#   'ANIX',
#   'ANNX',
#   'APM',
#   'APTO',
#   'APVO',
#   'AQST',
#   'ARAV',
#   'ARCT',
#   'ARDX',
#   'ARGX',
#   'ARTL',
#   'ARVN',
#   'ASLN',
#   'ASND',
#   'ASRT',
#   'ATNF',
#   'ATOS',
#   'ATRA',
#   'ATRI',
#   'ATXI',
#   'ATXS',
#   'AUPH',
#   'AURA',
#   'AUTL',
#   'AVIR',
#   'AVRO',
#   'AVTE',
#   'AVTX',
#   'AVXL',
#   'AWH',
#   'AXSM',
#   'AYTU',
#   'AZTA',
#   'BACK',
#   'BBIO',
#   'BCAB',
#   'BCEL',
#   'BCLI',
#   'BCPC',
#   'BCRX',
#   'BCTX',
#   'BCYC',
#   'BDRX',
#   'BDSX',
#   'BDTX',
#   'BFRI',
#   'BGNE',
#   'BGXX',
#   'BIAF',
#   'BIMI',
#   'BIOC',
#   'BIOX',
#   'BIVI',
#   'BLFS',
#   'BLRX',
#   'BLTE',
#   'BLUE',
#   'BMEA',
#   'BMRN',
#   'BNR',
#   'BNTC',
#   'BNTX',
#   'BOLT',
#   'BON',
#   'BPMC',
#   'BPTH',
#   'BPTS',
#   'BRKR',
#   'BRTX',
#   'BSGM',
#   'BTAI',
#   'BTMD',
#   'BVS',
#   'BVXV',
#   'BWV',
#   'BXRX',
#   'BYSI',
#   'CABA',
#   'CADL',
#   'CAPR',
#   'CARA',
#   'CASI',
#   'CCCC',
#   'CDMO',
#   'CELC',
#   'CELH',
#   'CELU',
#   'CERE',
#   'CERT',
#   'CFRX',
#   'CG',
#   'CGBD',
#   'CGEM',
#   'CGEN',
#   'CJJD',
#   'CKPT',
#   'CLDX',
#   'CLLS',
#   'CLNN',
#   'CLRB',
#   'CLSD',
#   'CMMB',
#   'CMND',
#   'CMPX',
#   'CMRX',
#   'CNEY',
#   'CNSP',
#   'CNTA',
#   'CNTB',
#   'CNTG',
#   'CNTX',
#   'COCO',
#   'COCP',
#   'CODX',
#   'COEP',
#   'COGT',
#   'COKE',
#   'CORT',
#   'COSM',
#   'CPRX',
#   'CRBP',
#   'CRBU',
#   'CRDF',
#   'CRDL',
#   'CRIS',
#   'CRNX',
#   'CRSP',
#   'CRVO',
#   'CRVS',
#   'CTKB',
#   'CTMX',
#   'CTSH',
#   'CTXR',
#   'CUE',
#   'CVAC',
#   'CYCC',
#   'CYCN',
#   'CYRX',
#   'CYT',
#   'CYTH',
#   'DARE',
#   'DAWN',
#   'DBTX',
#   'DBVT',
#   'DCPH',
#   'DERM',
#   'DMTK',
#   'DNLI',
#   'DOMH',
#   'DRMA',
#   'DRRX',
#   'DRTS',
#   'DSGN',
#   'DTIL',
#   'DVAX',
#   'DYAI',
#   'ECOR',
#   'EDAP',
#   'EDIT',
#   'EDSA',
#   'EFTR',
#   'EHTH',
#   'EIGR',
#   'ELDN',
#   'ELEV',
#   'ELOX',
#   'ELVN',
#   'ENSC',
#   'ENTA',
#   'EPIX',
#   'EQ',
#   'EQRX',
#   'ERAS',
#   'ESPR',
#   'ETNB',
#   'ETON',
#   'EVAX',
#   'EVLO',
#   'EVO',
#   'EVOK',
#   'EWTX',
#   'EXAI',
#   'EXAS',
#   'EXEL',
#   'EYEN',
#   'EYPT',
#   'FATE',
#   'FBIO',
#   'FBIOP',
#   'FENC',
#   'FGEN',
#   'FHTX',
#   'FIXX',
#   'FLEX',
#   'FLGT',
#   'FOLD',
#   'FREE',
#   'FRLN',
#   'FRTX',
#   'FULC',
#   'FUSN',
#   'FWBI',
#   'GALT',
#   'GANX',
#   'GBIO',
#   'GDRX',
#   'GEHC',
#   'GENE',
#   'GH',
#   'GHRS',
#   'GLSI',
#   'GLTO',
#   'GMAB',
#   'GMDA',
#   'GNPX',
#   'GOCO',
#   'GOVX',
#   'GRCL',
#   'GRPH',
#   'GRTS',
#   'GRTX',
#   'GTBP',
#   'GTH',
#   'GTHX',
#   'HAIN',
#   'HALO',
#   'HARP',
#   'HAS',
#   'HBIO',
#   'HCM',
#   'HCTI',
#   'HEPA',
#   'HILS',
#   'HLVX',
#   'HOLX',
#   'HON',
#   'HOOK',
#   'HOTH',
#   'HOWL',
#   'HRMY',
#   'HROW',
#   'HRTX',
#   'HSIC',
#   'HSTM',
#   'HUGE',
#   'HWKN',
#   'IBRX',
#   'ICLR',
#   'ICUI',
#   'ICVX',
#   'IDYA',
#   'IEP',
#   'IFRX',
#   'IGMS',
#   'IKT',
#   'ILMN',
#   'IMAB',
#   'IMCR',
#   'IMGN',
#   'IMNM',
#   'IMNN',
#   'IMPL',
#   'IMRX',
#   'IMTX',
#   'IMUX',
#   'IMVT',
#   'INAB',
#   'INBS',
#   'INCY',
#   'INFI',
#   'INM',
#   'INMB',
#   'INO',
#   'INSM',
#   'IOBT',
#   'IOVA',
#   'IPA',
#   'IPSC',
#   'ITCI',
#   'ITRM',
#   'IVVD',
#   'JAGX',
#   'JAKK',
#   'JAN',
#   'JANX',
#   'JAZZ',
#   'JD',
#   'JSPR',
#   'KA',
#   'KALA',
#   'KALV',
#   'KHC',
#   'KNSA',
#   'KNTE',
#   'KOD',
#   'KPRX',
#   'KPTI',
#   'KRBP',
#   'KRMD',
#   'KRON',
#   'KRTX',
#   'KTRA',
#   'KURA',
#   'KZR',
#   'LAB',
#   'LAKE',
#   'LBPH',
#   'LEGN',
#   'LEXX',
#   'LFMD',
#   'LGND',
#   'LGVN',
#   'LIFE',
#   'LIXT',
#   'LNTH',
#   'LPCN',
#   'LPTX',
#   'LSTA',
#   'LTRN',
#   'LUCD',
#   'LVTX',
#   'LXRX',
#   'LYEL',
#   'LYRA',
#   'MBIO',
#   'MBRX',
#   'MCRB',
#   'MDLZ',
#   'MDNA',
#   'MDVL',
#   'ME',
#   'MEDP',
#   'MEDS',
#   'MEIP',
#   'MGNX',
#   'MGTA',
#   'MGTX',
#   'MIRM',
#   'MLTX',
#   'MNOV',
#   'MNPR',
#   'MNST',
#   'MOR',
#   'MORF',
#   'MREO',
#   'MRKR',
#   'MRNA',
#   'MRNS',
#   'MRSN',
#   'MRTX',
#   'MRUS',
#   'MRVI',
#   'MTEM',
#   'MXCT',
#   'MYGN',
#   'MYMD',
#   'MYNZ',
#   'NBIX',
#   'NBSE',
#   'NCNA',
#   'NEOG',
#   'NERV',
#   'NEXI',
#   'NGM',
#   'NKTR',
#   'NKTX',
#   'NLSP',
#   'NLTX',
#   'NNOX',
#   'NOTV',
#   'NRIX',
#   'NRXP',
#   'NSTG',
#   'NTLA',
#   'NTRA',
#   'NUVL',
#   'NVAX',
#   'NVCR',
#   'NVCT',
#   'NXGL',
#   'NXTC',
#   'OABI',
#   'OCGN',
#   'OCUP',
#   'OCX',
#   'OFIX',
#   'OFLX',
#   'OLMA',
#   'OMER',
#   'OMGA',
#   'OMIC',
#   'ONCT',
#   'ONCY',
#   'ONTX',
#   'OPCH',
#   'OPGN',
#   'OPK',
#   'OPRX',
#   'OPTN',
#   'ORGS',
#   'ORIC',
#   'ORMP',
#   'ORTX',
#   'OSIS',
#   'OSUR',
#   'OTLK',
#   'OVID',
#   'PACB',
#   'PASG',
#   'PAVM',
#   'PAYS',
#   'PBLA',
#   'PBYI',
#   'PCSA',
#   'PCVX',
#   'PDCO',
#   'PDSB',
#   'PEP',
#   'PGEN',
#   'PHIO',
#   'PIRS',
#   'PLRX',
#   'PMCB',
#   'PMD',
#   'PMVP',
#   'PNT',
#   'POAI',
#   'PPBT',
#   'PRAX',
#   'PRE',
#   'PRLD',
#   'PRME',
#   'PRPO',
#   'PRTA',
#   'PRTG',
#   'PSNL',
#   'PSTV',
#   'PSTX',
#   'PTGX',
#   'PTPI',
#   'PULM',
#   'PWFL',
#   'PXMD',
#   'PYPD',
#   'PYXS',
#   'QLGN',
#   'QNRX',
#   'QTRX',
#   'QURE',
#   'RAIN',
#   'RANI',
#   'RAPT',
#   'RCKT',
#   'RDHL',
#   'REGN',
#   'REPL',
#   'REYN',
#   'RGEN',
#   'RGF',
#   'RGLS',
#   'RGNX',
#   'RIGL',
#   'RLAY',
#   'RLYB',
#   'RNA',
#   'RNAZ',
#   'RNLX',
#   'RNXT',
#   'ROIV',
#   'RPHM',
#   'RPID',
#   'RPRX',
#   'RPTX',
#   'RVLP',
#   'RVMD',
#   'RXRX',
#   'RZLT',
#   'SABS',
#   'SANA',
#   'SAVA',
#   'SBFM',
#   'SCPH',
#   'SCTL',
#   'SCWO',
#   'SCYX',
#   'SDGR',
#   'SELB',
#   'SGEN',
#   'SGMO',
#   'SHPH',
#   'SILO',
#   'SLDB',
#   'SLGC',
#   'SLGL',
#   'SLN',
#   'SLRX',
#   'SLS',
#   'SMMT',
#   'SMPL',
#   'SNCE',
#   'SNGX',
#   'SNPX',
#   'SNSE',
#   'SNTI',
#   'SNY',
#   'SONN',
#   'SOVO',
#   'SPRB',
#   'SPRC',
#   'SQL',
#   'SRCL',
#   'SRRK',
#   'SRZN',
#   'STER',
#   'STOK',
#   'STRO',
#   'STSS',
#   'STTK',
#   'SUPN',
#   'SURF',
#   'SWKH',
#   'SWTX',
#   'SXTC',
#   'SY',
#   'SYBX',
#   'SYNH',
#   'TARA',
#   'TBIO',
#   'TCON',
#   'TECH',
#   'TENX',
#   'TERN',
#   'TFFP',
#   'TGTX',
#   'THMO',
#   'THRX',
#   'THTX',
#   'TIL',
#   'TKLF',
#   'TKNO',
#   'TLRY',
#   'TLSA',
#   'TNGX',
#   'TNXP',
#   'TNYA',
#   'TOI',
#   'TOMZ',
#   'TRDA',
#   'TSHA',
#   'TSVT',
#   'TTNP',
#   'TVTX',
#   'TWST',
#   'TXG',
#   'TXMD',
#   'TYRA',
#   'UBX',
#   'UNCY',
#   'URGN',
#   'UTHR',
#   'VACC',
#   'VANI',
#   'VBIV',
#   'VBLT',
#   'VCEL',
#   'VCNX',
#   'VERA',
#   'VERU',
#   'VERV',
#   'VIGL',
#   'VINC',
#   'VIRI',
#   'VIRX',
#   'VKTX',
#   'VOR',
#   'VRAX',
#   'VRCA',
#   'VRDN',
#   'VRNA',
#   'VRPX',
#   'VRTX',
#   'VSTM',
#   'VTGN',
#   'VTRS',
#   'VTVT',
#   'VXRT',
#   'VYGR',
#   'VYNE',
#   'WBA',
#   'WGS',
#   'WVE',
#   'XBIO',
#   'XCUR',
#   'XERS',
#   'XGN',
#   'XLO',
#   'XNCR',
#   'XOMA',
#   'XRTX',
#   'YI',
#   'YMAB',
#   'ZBRA',
#   'ZLAB',
#   'ZNTL',
#   'ZTEK',
#   'ZVRA',
#   'ZVSA',
#   'ZYME',
#   'ZYNE'},
#  'transport': {'AAL',
#   'ACTG',
#   'ADSK',
#   'ADUS',
#   'AEY',
#   'AIHS',
#   'AKAM',
#   'ALCO',
#   'ALGT',
#   'ALTO',
#   'ALYA',
#   'AMEH',
#   'AMSC',
#   'AMTI',
#   'AMTX',
#   'ANSS',
#   'APPN',
#   'APPS',
#   'APYX',
#   'ARAY',
#   'ARCB',
#   'ARCT',
#   'AREC',
#   'ASND',
#   'ASTL',
#   'ATNI',
#   'ATRI',
#   'ATSG',
#   'ATXG',
#   'AVAH',
#   'AVNW',
#   'AYRO',
#   'BBIO',
#   'BBSI',
#   'BCDA',
#   'BCPC',
#   'BDRX',
#   'BELFB',
#   'BIOR',
#   'BKNG',
#   'BLDE',
#   'BLFS',
#   'BLIN',
#   'BLNK',
#   'BLPH',
#   'BLZE',
#   'BOOM',
#   'BPTH',
#   'BSY',
#   'BTCY',
#   'BWMN',
#   'CACO',
#   'CAR',
#   'CASS',
#   'CBRL',
#   'CCOI',
#   'CCSI',
#   'CELH',
#   'CG',
#   'CHRW',
#   'CHSCM',
#   'CHSCP',
#   'CIGI',
#   'CLSD',
#   'CMCO',
#   'CNDT',
#   'CONN',
#   'COST',
#   'CPLP',
#   'CPRT',
#   'CPSH',
#   'CPSI',
#   'CRAI',
#   'CRGE',
#   'CRNT',
#   'CSWI',
#   'CSX',
#   'CTAS',
#   'CTRM',
#   'CVBF',
#   'CYRX',
#   'CYTO',
#   'DADA',
#   'DAKT',
#   'DARE',
#   'DCGO',
#   'DCTH',
#   'DHC',
#   'DHIL',
#   'DLO',
#   'DOX',
#   'DRS',
#   'DSKE',
#   'DXPE',
#   'EDRY',
#   'EEFT',
#   'EGIO',
#   'EH',
#   'EJH',
#   'EM',
#   'ENSG',
#   'ENTG',
#   'ERIC',
#   'ESEA',
#   'EVTV',
#   'EXLS',
#   'EXPD',
#   'EXPO',
#   'EYEN',
#   'EYPT',
#   'EZFL',
#   'FCBC',
#   'FCEL',
#   'FDUS',
#   'FFIV',
#   'FIP',
#   'FLNC',
#   'FORA',
#   'FRGT',
#   'FRME',
#   'FROG',
#   'FSTR',
#   'FTAI',
#   'FUV',
#   'FWRD',
#   'GDYN',
#   'GEHC',
#   'GLAD',
#   'GLBS',
#   'GLNG',
#   'GOEV',
#   'GOGL',
#   'GP',
#   'GPP',
#   'GPRE',
#   'GRAB',
#   'GRRR',
#   'GTHX',
#   'HA',
#   'HALO',
#   'HCTI',
#   'HEES',
#   'HEPS',
#   'HLIT',
#   'HLTH',
#   'HRTX',
#   'HSIC',
#   'HTLD',
#   'HUBG',
#   'HUMA',
#   'HURN',
#   'HYFM',
#   'IBEX',
#   'ICHR',
#   'IDEX',
#   'IEP',
#   'IMPP',
#   'INFN',
#   'INNV',
#   'INO',
#   'INSG',
#   'INVZ',
#   'IPGP',
#   'IPW',
#   'IRIX',
#   'JBHT',
#   'JBLU',
#   'JKHY',
#   'JXJT',
#   'KAVL',
#   'KC',
#   'KRMD',
#   'LECO',
#   'LEGH',
#   'LFLY',
#   'LFST',
#   'LFUS',
#   'LILM',
#   'LINC',
#   'LITE',
#   'LKCO',
#   'LNTH',
#   'LPCN',
#   'LSTR',
#   'LYFT',
#   'LYRA',
#   'MANH',
#   'MCBS',
#   'MDLZ',
#   'MDRX',
#   'MFIC',
#   'MGIC',
#   'MKSI',
#   'MLKN',
#   'MMLP',
#   'MMSI',
#   'MNDO',
#   'MNKD',
#   'MNTS',
#   'MOBQ',
#   'MODV',
#   'MRTN',
#   'MSBI',
#   'MTRX',
#   'MXL',
#   'MYRG',
#   'NATI',
#   'NDSN',
#   'NEPT',
#   'NKLA',
#   'NNBR',
#   'NNDM',
#   'NNOX',
#   'NOVT',
#   'NSPR',
#   'NTCT',
#   'NVTS',
#   'NXGL',
#   'NXTP',
#   'ODFL',
#   'OFLX',
#   'OMAB',
#   'OP',
#   'OPAL',
#   'OPBK',
#   'OPTN',
#   'ORMP',
#   'PAA',
#   'PAGP',
#   'PANL',
#   'PATK',
#   'PCB',
#   'PLUG',
#   'PODD',
#   'PRFT',
#   'PRGS',
#   'PRTG',
#   'PSEC',
#   'PSHG',
#   'PSMT',
#   'PTMN',
#   'PTSI',
#   'PULM',
#   'PWFL',
#   'PXS',
#   'PZZA',
#   'QH',
#   'QIPT',
#   'QRHC',
#   'RAIL',
#   'RANI',
#   'RAVE',
#   'RBBN',
#   'RCEL',
#   'RCON',
#   'RDWR',
#   'REE',
#   'REKR',
#   'RGLS',
#   'RGNX',
#   'RIVN',
#   'RMBL',
#   'ROP',
#   'RPD',
#   'RRBI',
#   'RXST',
#   'SABR',
#   'SAIA',
#   'SBLK',
#   'SCKT',
#   'SCSC',
#   'SGC',
#   'SGLY',
#   'SHYF',
#   'SILK',
#   'SKIN',
#   'SKYT',
#   'SLGL',
#   'SLNG',
#   'SMTC',
#   'SONM',
#   'SONN',
#   'SOPA',
#   'SP',
#   'SPI',
#   'SPNS',
#   'STAA',
#   'STER',
#   'STGW',
#   'STLD',
#   'STRL',
#   'SVRE',
#   'SWVL',
#   'SYTA',
#   'TAOP',
#   'TASK',
#   'TCOM',
#   'TCPC',
#   'TEAM',
#   'TFIN',
#   'TITN',
#   'TNDM',
#   'TOPS',
#   'TRKA',
#   'TRMB',
#   'TRMD',
#   'TTEC',
#   'TTNP',
#   'TUSK',
#   'TWKS',
#   'TWOU',
#   'UAL',
#   'UCTT',
#   'UGRO',
#   'ULCC',
#   'ULH',
#   'USEA',
#   'UTHR',
#   'UTMD',
#   'UXIN',
#   'VEEE',
#   'VEV',
#   'VIA',
#   'VIASP',
#   'VLCN',
#   'VOD',
#   'VRME',
#   'VRNS',
#   'VRPX',
#   'VRRM',
#   'VTNR',
#   'WERN',
#   'WEST',
#   'WKHS',
#   'WPRT',
#   'XAIR',
#   'XBIO',
#   'ZBRA',
#   'ZEUS',
#   'ZI',
#   'ZS',
#   'ZYNE',
#   'ZYXI'},
#  'data': {'AAOI',
#   'AAON',
#   'AAPL',
#   'ACON',
#   'ACVA',
#   'ADBE',
#   'ADI',
#   'ADP',
#   'ADSK',
#   'ADTH',
#   'AEHL',
#   'AEY',
#   'AGIL',
#   'AGYS',
#   'AKAM',
#   'ALAR',
#   'ALLT',
#   'ALPP',
#   'ALRM',
#   'ALTR',
#   'ALYA',
#   'AMD',
#   'AMPL',
#   'AMSWA',
#   'ANY',
#   'AOSL',
#   'APLD',
#   'APPF',
#   'APPN',
#   'ARAY',
#   'ARLP',
#   'ARRY',
#   'ATER',
#   'ATNI',
#   'AUR',
#   'AVGO',
#   'AVPT',
#   'AWH',
#   'AXON',
#   'AXTI',
#   'AZPN',
#   'BASE',
#   'BELFB',
#   'BFC',
#   'BGC',
#   'BIDU',
#   'BKYI',
#   'BLKB',
#   'BLNK',
#   'BLZE',
#   'BNGO',
#   'BNR',
#   'BRQS',
#   'BRZE',
#   'BSQR',
#   'BTAI',
#   'BTCY',
#   'CASA',
#   'CCCS',
#   'CCOI',
#   'CCSI',
#   'CD',
#   'CDLX',
#   'CDW',
#   'CERT',
#   'CFLT',
#   'CGNT',
#   'CHDN',
#   'CHEK',
#   'CHKP',
#   'CHTR',
#   'CIFR',
#   'CISO',
#   'CLBT',
#   'CLEU',
#   'CLPS',
#   'CLSK',
#   'CMAX',
#   'CME',
#   'CMTL',
#   'CNET',
#   'CNSL',
#   'CNXN',
#   'CODA',
#   'COHU',
#   'COMM',
#   'COMS',
#   'CPSI',
#   'CRGE',
#   'CRGO',
#   'CRWD',
#   'CSCO',
#   'CTKB',
#   'CUEN',
#   'CVLT',
#   'CXDO',
#   'CYN',
#   'DCBO',
#   'DDOG',
#   'DGII',
#   'DGLY',
#   'DISH',
#   'DOMO',
#   'DOX',
#   'DPRO',
#   'DRIO',
#   'DSP',
#   'DTST',
#   'DUO',
#   'DXCM',
#   'DZSI',
#   'EBON',
#   'EDTK',
#   'EGIO',
#   'EMKR',
#   'ENG',
#   'ERIC',
#   'ESLT',
#   'EVGO',
#   'EXLS',
#   'EXPO',
#   'EXTR',
#   'FARO',
#   'FCEL',
#   'FCUV',
#   'FELE',
#   'FFIV',
#   'FIVN',
#   'FLEX',
#   'FLGT',
#   'FLNT',
#   'FNGR',
#   'FOLD',
#   'FORA',
#   'FORR',
#   'FRSX',
#   'FSTR',
#   'FTFT',
#   'FTHM',
#   'FUTU',
#   'FYBR',
#   'GDS',
#   'GEN',
#   'GEOS',
#   'GH',
#   'GOCO',
#   'GOOG',
#   'GOOGL',
#   'GPRO',
#   'GRRR',
#   'GTH',
#   'HBIO',
#   'HCAT',
#   'HCP',
#   'HCTI',
#   'HEPS',
#   'HHS',
#   'HITI',
#   'HLIT',
#   'HLTH',
#   'HOLI',
#   'HOLO',
#   'HON',
#   'HTBK',
#   'HTCR',
#   'HUBC',
#   'HYW',
#   'ICFI',
#   'ICLK',
#   'ICLR',
#   'IDAI',
#   'IDEX',
#   'IDN',
#   'IESC',
#   'IFBD',
#   'IHRT',
#   'IIIV',
#   'INFN',
#   'INPX',
#   'INSG',
#   'INTA',
#   'INTC',
#   'INTZ',
#   'INVE',
#   'INVZ',
#   'IPA',
#   'IPGP',
#   'IPWR',
#   'IRDM',
#   'IREN',
#   'IRTC',
#   'ISPC',
#   'ISUN',
#   'ITRI',
#   'ITRN',
#   'IVDA',
#   'JAMF',
#   'JD',
#   'JG',
#   'JKHY',
#   'JXJT',
#   'JZ',
#   'KC',
#   'KERN',
#   'KFRC',
#   'KITT',
#   'KLTR',
#   'KSCP',
#   'LBRDA',
#   'LBRDK',
#   'LBTYA',
#   'LBTYK',
#   'LFUS',
#   'LIFW',
#   'LILA',
#   'LILAK',
#   'LITE',
#   'LIZI',
#   'LKCO',
#   'LPTH',
#   'LSAK',
#   'LSXMA',
#   'LSXMK',
#   'LTRN',
#   'LTRY',
#   'LVOX',
#   'LWLG',
#   'LYFT',
#   'MARK',
#   'MCLD',
#   'MDB',
#   'MDRX',
#   'MEDP',
#   'MGIC',
#   'MIGI',
#   'MINM',
#   'MITK',
#   'MKTX',
#   'MKUL',
#   'MLGO',
#   'MNDO',
#   'MOB',
#   'MOBQ',
#   'MORN',
#   'MRAM',
#   'MRVL',
#   'MSFT',
#   'MSTR',
#   'MTTR',
#   'MU',
#   'MVLA',
#   'MXL',
#   'MYRG',
#   'NATI',
#   'NCNO',
#   'NEWT',
#   'NICE',
#   'NN',
#   'NNOX',
#   'NOVT',
#   'NPCE',
#   'NSIT',
#   'NSTG',
#   'NTAP',
#   'NTCT',
#   'NTES',
#   'NTGR',
#   'NTNX',
#   'NTRA',
#   'NTWK',
#   'NVDA',
#   'NVEC',
#   'NVTS',
#   'NWS',
#   'NWSA',
#   'NXGN',
#   'NXPL',
#   'OBLG',
#   'OESX',
#   'OKTA',
#   'OLK',
#   'ONDS',
#   'OSPN',
#   'OSS',
#   'OTEX',
#   'OTMO',
#   'PANW',
#   'PBTS',
#   'PCTI',
#   'PCTY',
#   'PDFS',
#   'PEGA',
#   'PHUN',
#   'PI',
#   'PMD',
#   'PMTS',
#   'POET',
#   'PRFT',
#   'PRGS',
#   'PSNL',
#   'PTC',
#   'PUBM',
#   'PWFL',
#   'QCOM',
#   'QMCO',
#   'QSI',
#   'RBBN',
#   'RCON',
#   'RDWR',
#   'REKR',
#   'RFIL',
#   'RGP',
#   'RGTI',
#   'RILY',
#   'RILYP',
#   'RIOT',
#   'RMBS',
#   'RNLX',
#   'ROP',
#   'RPD',
#   'RTC',
#   'RVSN',
#   'RVYL',
#   'RWAY',
#   'RXRX',
#   'RXT',
#   'SANM',
#   'SASI',
#   'SBET',
#   'SCKT',
#   'SCSC',
#   'SHCR',
#   'SHEN',
#   'SIDU',
#   'SIFY',
#   'SIMO',
#   'SIRI',
#   'SLNH',
#   'SMCI',
#   'SMTC',
#   'SNCE',
#   'SNCR',
#   'SOPA',
#   'SOPH',
#   'SPLK',
#   'SPT',
#   'SQL',
#   'SRAD',
#   'SSNC',
#   'SSYS',
#   'STGW',
#   'STIX',
#   'STLD',
#   'STRL',
#   'STX',
#   'SYTA',
#   'TAOP',
#   'TASK',
#   'TCOM',
#   'TEAM',
#   'TENB',
#   'TER',
#   'THRN',
#   'TIGO',
#   'TITN',
#   'TLS',
#   'TMUS',
#   'TNDM',
#   'TRHC',
#   'TRKA',
#   'TRMB',
#   'TRMR',
#   'TROO',
#   'TRUE',
#   'TTD',
#   'TTEC',
#   'TTEK',
#   'TTMI',
#   'TTWO',
#   'TW',
#   'TWKS',
#   'TWST',
#   'TXN',
#   'UCL',
#   'UPLD',
#   'UPWK',
#   'USIO',
#   'VC',
#   'VERI',
#   'VERX',
#   'VIAV',
#   'VIRT',
#   'VNET',
#   'VOD',
#   'VRAR',
#   'VRAX',
#   'VRME',
#   'VRNS',
#   'VRNT',
#   'VRSK',
#   'VRSN',
#   'VSAT',
#   'WDAY',
#   'WDC',
#   'WETG',
#   'WGS',
#   'WIMI',
#   'WKHS',
#   'WKME',
#   'WORX',
#   'WTFC',
#   'WTFCM',
#   'WTFCP',
#   'WTW',
#   'XELA',
#   'XNET',
#   'YI',
#   'ZBRA',
#   'ZENV',
#   'ZFOX',
#   'ZM',
#   'ZS'},
#  'retail': {'AAON',
#   'AAPL',
#   'ABCB',
#   'ACGL',
#   'ACGLN',
#   'ACGLO',
#   'ACNB',
#   'ACTG',
#   'ADBE',
#   'ADV',
#   'AEP',
#   'AMAL',
#   'AMD',
#   'AMNB',
#   'AMRK',
#   'AMZN',
#   'ANIP',
#   'APOG',
#   'ARCB',
#   'ARCC',
#   'ARHS',
#   'ARKO',
#   'ASO',
#   'ASTI',
#   'ATLC',
#   'ATLCP',
#   'ATNI',
#   'ATVI',
#   'ATXG',
#   'AUVI',
#   'AVO',
#   'AZ',
#   'BANF',
#   'BASE',
#   'BCBP',
#   'BECN',
#   'BGFV',
#   'BIMI',
#   'BIRD',
#   'BLIN',
#   'BLNK',
#   'BOKF',
#   'BOOM',
#   'BPOP',
#   'BPYPO',
#   'BPYPP',
#   'BRKL',
#   'BRSH',
#   'BSFC',
#   'BSRR',
#   'BSVN',
#   'BTB',
#   'BUSE',
#   'BYND',
#   'CAKE',
#   'CASS',
#   'CBSH',
#   'CCBG',
#   'CDXC',
#   'CELH',
#   'CFFN',
#   'CFLT',
#   'CG',
#   'CHDN',
#   'CHRW',
#   'CHSCM',
#   'CHSCP',
#   'CJJD',
#   'CLVR',
#   'CNXC',
#   'COCO',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONN',
#   'COSM',
#   'CPSS',
#   'CRAI',
#   'CRCT',
#   'CREX',
#   'CRMT',
#   'CRON',
#   'CROX',
#   'CRSR',
#   'CSGP',
#   'CSGS',
#   'CTIB',
#   'CTLP',
#   'CTRN',
#   'CTSH',
#   'CUEN',
#   'CVCO',
#   'CVGW',
#   'CVLY',
#   'CWCO',
#   'CZR',
#   'DADA',
#   'DBX',
#   'DCFC',
#   'DISH',
#   'DKNG',
#   'DLTR',
#   'DOGZ',
#   'DORM',
#   'DRTT',
#   'DRVN',
#   'DXLG',
#   'EA',
#   'EBC',
#   'EBTC',
#   'EDUC',
#   'EEFT',
#   'EGAN',
#   'ELYS',
#   'ESQ',
#   'EVBG',
#   'EXC',
#   'EXLS',
#   'EXPE',
#   'EXTR',
#   'EYE',
#   'FAST',
#   'FBMS',
#   'FCBC',
#   'FCFS',
#   'FCNCA',
#   'FCNCO',
#   'FCNCP',
#   'FDUS',
#   'FELE',
#   'FGI',
#   'FHB',
#   'FIBK',
#   'FITB',
#   'FITBO',
#   'FITBP',
#   'FIVE',
#   'FIVN',
#   'FIZZ',
#   'FLGC',
#   'FLIC',
#   'FLNT',
#   'FNCB',
#   'FNKO',
#   'FORD',
#   'FOSL',
#   'FRHC',
#   'FROG',
#   'FRPH',
#   'FRPT',
#   'FTNT',
#   'FWRD',
#   'GABC',
#   'GDYN',
#   'GEN',
#   'GFAI',
#   'GIII',
#   'GIPR',
#   'GNLN',
#   'GPRO',
#   'GRRR',
#   'GRWG',
#   'GT',
#   'HAIN',
#   'HAS',
#   'HBNC',
#   'HBT',
#   'HEAR',
#   'HELE',
#   'HEPS',
#   'HFWA',
#   'HHS',
#   'HIBB',
#   'HITI',
#   'HLMN',
#   'HNST',
#   'HOFT',
#   'HQI',
#   'HTBK',
#   'HTLD',
#   'HUBG',
#   'HWC',
#   'IBEX',
#   'IBOC',
#   'IDN',
#   'IEP',
#   'IFBD',
#   'IMKTA',
#   'INTC',
#   'INTU',
#   'IPAR',
#   'IPW',
#   'IRBT',
#   'JAKK',
#   'JD',
#   'JG',
#   'JJSF',
#   'JKHY',
#   'JOAN',
#   'JRSH',
#   'JUPW',
#   'JVA',
#   'JWEL',
#   'JXJT',
#   'JZXN',
#   'KDP',
#   'KERN',
#   'KFRC',
#   'KHC',
#   'KOSS',
#   'KPLT',
#   'KRKR',
#   'KRT',
#   'LANC',
#   'LBC',
#   'LE',
#   'LECO',
#   'LEGH',
#   'LFLY',
#   'LGHL',
#   'LKFN',
#   'LKQ',
#   'LNT',
#   'LOGI',
#   'LSTR',
#   'LSXMA',
#   'LSXMK',
#   'LUCY',
#   'LULU',
#   'LVLU',
#   'MANH',
#   'MAPS',
#   'MARK',
#   'MAT',
#   'MATW',
#   'MBCN',
#   'MBIN',
#   'MBINM',
#   'MBINO',
#   'MBWM',
#   'MDLZ',
#   'MDRX',
#   'MDVL',
#   'MEDS',
#   'MELI',
#   'MF',
#   'MFIC',
#   'MINM',
#   'MLCO',
#   'MLKN',
#   'MMLP',
#   'MNST',
#   'MOFG',
#   'MSBI',
#   'MSEX',
#   'MSFT',
#   'MSGM',
#   'MTTR',
#   'NATH',
#   'NBTB',
#   'NEOG',
#   'NEPT',
#   'NKSH',
#   'NOGN',
#   'NRIM',
#   'NSIT',
#   'NTGR',
#   'NTNX',
#   'NWL',
#   'NWTN',
#   'OBLG',
#   'OCFC',
#   'OCSL',
#   'ODP',
#   'OESX',
#   'OGI',
#   'OLB',
#   'OLLI',
#   'OLPX',
#   'OMAB',
#   'ONEW',
#   'OPEN',
#   'OPRT',
#   'ORLY',
#   'OSTK',
#   'OZK',
#   'OZKAP',
#   'PAYS',
#   'PCAR',
#   'PCTY',
#   'PDCO',
#   'PEBO',
#   'PECO',
#   'PEP',
#   'PETQ',
#   'PFIS',
#   'PHUN',
#   'PI',
#   'PIK',
#   'PLBY',
#   'PLCE',
#   'PLMR',
#   'POOL',
#   'PPC',
#   'PRAA',
#   'PRPL',
#   'PRTH',
#   'PSEC',
#   'PTON',
#   'PTSI',
#   'PTVE',
#   'PWFL',
#   'PWOD',
#   'PYCR',
#   'QCRH',
#   'QDEL',
#   'QRHC',
#   'QRTEA',
#   'QRTEP',
#   'RAVE',
#   'RAYA',
#   'RDVT',
#   'REBN',
#   'REE',
#   'REG',
#   'RELI',
#   'REYN',
#   'RGF',
#   'RIBT',
#   'RICK',
#   'RMCF',
#   'RNST',
#   'ROCK',
#   'ROKU',
#   'ROST',
#   'RPD',
#   'RRBI',
#   'RTL',
#   'RTLPO',
#   'RTLPP',
#   'RUN',
#   'RUSHA',
#   'RVYL',
#   'RWAY',
#   'SASR',
#   'SBT',
#   'SBUX',
#   'SCHL',
#   'SCHN',
#   'SCKT',
#   'SCSC',
#   'SCVL',
#   'SCWX',
#   'SFT',
#   'SGC',
#   'SHOO',
#   'SHYF',
#   'SIFY',
#   'SIGI',
#   'SIRI',
#   'SLM',
#   'SMPL',
#   'SMSI',
#   'SNAX',
#   'SNBR',
#   'SNDL',
#   'SNEX',
#   'SNT',
#   'SOLO',
#   'SONO',
#   'SOVO',
#   'SP',
#   'SPFI',
#   'SPTN',
#   'SPWH',
#   'SQFT',
#   'SRAD',
#   'SRCL',
#   'STBA',
#   'STBX',
#   'STCN',
#   'STER',
#   'STIX',
#   'STKH',
#   'STKL',
#   'STRS',
#   'STX',
#   'SVC',
#   'SWAG',
#   'SWBI',
#   'SWVL',
#   'SYBT',
#   'SYM',
#   'TCBX',
#   'TFSL',
#   'TILE',
#   'TIVC',
#   'TKLF',
#   'TLRY',
#   'TMUS',
#   'TOUR',
#   'TOWN',
#   'TSCO',
#   'TSLA',
#   'TTWO',
#   'TW',
#   'TWKS',
#   'TXMD',
#   'UBSI',
#   'UCBI',
#   'UCBIO',
#   'UEIC',
#   'UFPI',
#   'UGRO',
#   'ULBI',
#   'ULH',
#   'ULTA',
#   'UMBF',
#   'UPBD',
#   'UPLD',
#   'URBN',
#   'USIO',
#   'UXIN',
#   'VABK',
#   'VERX',
#   'VFF',
#   'VIA',
#   'VIASP',
#   'VLGEA',
#   'VLY',
#   'VLYPO',
#   'VLYPP',
#   'VMAR',
#   'VNET',
#   'VOD',
#   'VRA',
#   'VRM',
#   'VRTX',
#   'VTRS',
#   'WABC',
#   'WASH',
#   'WBA',
#   'WDAY',
#   'WDC',
#   'WDFC',
#   'WERN',
#   'WEST',
#   'WEYS',
#   'WIMI',
#   'WINA',
#   'WKSP',
#   'WMG',
#   'WMPN',
#   'WNEB',
#   'WSBC',
#   'WSBCP',
#   'WSC',
#   'WTER',
#   'WTFC',
#   'WTFCM',
#   'WTFCP',
#   'WYNN',
#   'XEL',
#   'XP',
#   'XWEL',
#   'YI',
#   'ZBRA',
#   'ZFOX',
#   'ZI',
#   'ZION',
#   'ZS',
#   'ZUMZ'},
#  'bank': {'AAPL',
#   'ABCB',
#   'ACGL',
#   'ACGLN',
#   'ACGLO',
#   'ACIW',
#   'ACNB',
#   'ACT',
#   'AEY',
#   'AFCG',
#   'AGBA',
#   'AGNC',
#   'AGNCL',
#   'AGNCM',
#   'AGNCN',
#   'AGNCO',
#   'AGNCP',
#   'AIHS',
#   'ALKT',
#   'ALRM',
#   'ALRS',
#   'ALTI',
#   'ALTR',
#   'AMAL',
#   'AMNB',
#   'AMRK',
#   'AMSC',
#   'APCX',
#   'ARCC',
#   'AROW',
#   'ASUR',
#   'ATLC',
#   'ATLCP',
#   'ATLO',
#   'AUID',
#   'BANF',
#   'BANR',
#   'BCBP',
#   'BCML',
#   'BEAT',
#   'BFC',
#   'BFIN',
#   'BFST',
#   'BGC',
#   'BKCC',
#   'BL',
#   'BLFY',
#   'BLIN',
#   'BMRC',
#   'BOKF',
#   'BPOP',
#   'BPRN',
#   'BRKL',
#   'BSRR',
#   'BSVN',
#   'BUSE',
#   'BWB',
#   'CAC',
#   'CACC',
#   'CARE',
#   'CARV',
#   'CASS',
#   'CATY',
#   'CBAN',
#   'CBNK',
#   'CBSH',
#   'CCB',
#   'CCBG',
#   'CCNE',
#   'CDLX',
#   'CFB',
#   'CFFN',
#   'CG',
#   'CGBD',
#   'CHCO',
#   'CIGI',
#   'CLBK',
#   'CLPS',
#   'CNOB',
#   'CNOBP',
#   'CNXC',
#   'COFS',
#   'COLB',
#   'CONN',
#   'COOP',
#   'CPSS',
#   'CREX',
#   'CSTR',
#   'CSWC',
#   'CTBI',
#   'CUEN',
#   'CVBF',
#   'CVCO',
#   'CVLT',
#   'CVLY',
#   'CZFS',
#   'CZNC',
#   'DAVE',
#   'DCOM',
#   'DCOMP',
#   'DTST',
#   'EBC',
#   'EBTC',
#   'ECBK',
#   'ECPG',
#   'EEFT',
#   'EFSC',
#   'ESQ',
#   'ESSA',
#   'EWBC',
#   'EXLS',
#   'EXPD',
#   'EZPW',
#   'FBIZ',
#   'FBMS',
#   'FBNC',
#   'FCBC',
#   'FCFS',
#   'FCNCA',
#   'FCNCO',
#   'FCNCP',
#   'FDUS',
#   'FFBC',
#   'FFIC',
#   'FFIN',
#   'FGBI',
#   'FHB',
#   'FIBK',
#   'FISI',
#   'FITB',
#   'FITBO',
#   'FITBP',
#   'FIVN',
#   'FLIC',
#   'FMAO',
#   'FNCB',
#   'FNLC',
#   'FRHC',
#   'FRME',
#   'FRST',
#   'FSBC',
#   'FSEA',
#   'FSV',
#   'FTHM',
#   'FULT',
#   'FULTP',
#   'FVCB',
#   'GABC',
#   'GAIN',
#   'GBDC',
#   'GCBC',
#   'GEN',
#   'GGAL',
#   'GLAD',
#   'GLRE',
#   'GRNQ',
#   'GSBC',
#   'HAFC',
#   'HBAN',
#   'HBANM',
#   'HBANP',
#   'HBNC',
#   'HBT',
#   'HFWA',
#   'HIFS',
#   'HONE',
#   'HOPE',
#   'HTBK',
#   'HTLF',
#   'HWBK',
#   'HWC',
#   'HYW',
#   'IBEX',
#   'IBOC',
#   'ICMB',
#   'IDEX',
#   'IDN',
#   'INDB',
#   'INTA',
#   'INTR',
#   'INTU',
#   'JG',
#   'JKHY',
#   'JMSB',
#   'KRNY',
#   'LBAI',
#   'LBC',
#   'LKFN',
#   'LNKB',
#   'LPLA',
#   'LPRO',
#   'LSAK',
#   'LSEA',
#   'LX',
#   'MBCN',
#   'MBIN',
#   'MBINM',
#   'MBINO',
#   'MBWM',
#   'MCBS',
#   'MELI',
#   'MFIC',
#   'MNSB',
#   'MOFG',
#   'MOGO',
#   'MOND',
#   'MORN',
#   'MRAI',
#   'MRBK',
#   'MSBI',
#   'MSTR',
#   'MVBF',
#   'MYFW',
#   'NAVI',
#   'NBN',
#   'NBTB',
#   'NCNO',
#   'NECB',
#   'NEWT',
#   'NFBK',
#   'NKSH',
#   'NRDS',
#   'NRIM',
#   'NTRS',
#   'NTRSO',
#   'NTWK',
#   'NWFL',
#   'NXTP',
#   'NYMT',
#   'NYMTM',
#   'NYMTN',
#   'OBT',
#   'OCCI',
#   'OCFC',
#   'OLB',
#   'ONB',
#   'ONBPO',
#   'ONBPP',
#   'OPBK',
#   'OPRT',
#   'OSBC',
#   'OXLC',
#   'OXLCM',
#   'OXSQ',
#   'OZK',
#   'OZKAP',
#   'PACW',
#   'PACWP',
#   'PALT',
#   'PAX',
#   'PBFS',
#   'PCAR',
#   'PCB',
#   'PDLB',
#   'PEBO',
#   'PFC',
#   'PFG',
#   'PFIS',
#   'PGC',
#   'PGY',
#   'PI',
#   'PKBK',
#   'PMTS',
#   'PNFP',
#   'PNFPP',
#   'PPBI',
#   'PRAA',
#   'PRCH',
#   'PRTH',
#   'PSEC',
#   'PT',
#   'PTMN',
#   'PVBC',
#   'PWOD',
#   'PWP',
#   'PYPL',
#   'QCRH',
#   'QFIN',
#   'RBB',
#   'RBCAA',
#   'REFI',
#   'RILY',
#   'RILYP',
#   'RNST',
#   'RPAY',
#   'RRBI',
#   'RUSHA',
#   'RWAY',
#   'SASR',
#   'SBRA',
#   'SBSI',
#   'SBT',
#   'SEVN',
#   'SFNC',
#   'SFST',
#   'SHBI',
#   'SHFS',
#   'SIGI',
#   'SLM',
#   'SMBC',
#   'SMBK',
#   'SNEX',
#   'SOFI',
#   'SPFI',
#   'SRCE',
#   'SSB',
#   'SSBK',
#   'SSNC',
#   'STBA',
#   'STER',
#   'SYBT',
#   'TC',
#   'TCBI',
#   'TCBIO',
#   'TCBK',
#   'TCBX',
#   'TCPC',
#   'TFIN',
#   'TFSL',
#   'THFF',
#   'THRY',
#   'TIGO',
#   'TOWN',
#   'TPG',
#   'TREE',
#   'TRIN',
#   'TRMK',
#   'TROO',
#   'TRST',
#   'TRUE',
#   'TW',
#   'UBFO',
#   'UBSI',
#   'UCBI',
#   'UCBIO',
#   'UMBF',
#   'UPST',
#   'USCB',
#   'USIO',
#   'UVSP',
#   'VABK',
#   'VINP',
#   'VLY',
#   'VLYPO',
#   'VLYPP',
#   'VOD',
#   'WABC',
#   'WAFD',
#   'WAFDP',
#   'WASH',
#   'WMPN',
#   'WNEB',
#   'WRLD',
#   'WSBC',
#   'WSBCP',
#   'WSBF',
#   'WSFS',
#   'WTBA',
#   'WTFC',
#   'WTFCM',
#   'WTFCP',
#   'WTW',
#   'XELA',
#   'XP',
#   'Z',
#   'ZG',
#   'ZION'},
#  'game': {'AAPL',
#   'ADEA',
#   'AGAE',
#   'AKAM',
#   'AMD',
#   'AOSL',
#   'API',
#   'ASO',
#   'ATVI',
#   'BASE',
#   'BHAT',
#   'BILI',
#   'BNMV',
#   'BOXL',
#   'BRAG',
#   'CFLT',
#   'CG',
#   'CHDN',
#   'CONN',
#   'CREX',
#   'CRSR',
#   'CSSE',
#   'CSSEP',
#   'CURI',
#   'CZR',
#   'DISH',
#   'DKNG',
#   'DLO',
#   'DLPN',
#   'DOYU',
#   'EA',
#   'EBET',
#   'EGLX',
#   'ELYS',
#   'FAZE',
#   'FIVE',
#   'FNKO',
#   'GAME',
#   'GAN',
#   'GDEN',
#   'GLPI',
#   'GMBL',
#   'GMGI',
#   'GRVY',
#   'GSMG',
#   'HAS',
#   'HEAR',
#   'HUT',
#   'IDCC',
#   'IMMR',
#   'IMOS',
#   'INSE',
#   'IQ',
#   'JAKK',
#   'JG',
#   'KC',
#   'LNW',
#   'LOGI',
#   'LTRY',
#   'MAT',
#   'MFIC',
#   'MLCO',
#   'MLGO',
#   'MMV',
#   'MOMO',
#   'MOXC',
#   'MSFT',
#   'MSGM',
#   'MYPS',
#   'NEGG',
#   'NFLX',
#   'NGMS',
#   'NN',
#   'NTES',
#   'NVDA',
#   'NXTP',
#   'OPRA',
#   'PENN',
#   'PHUN',
#   'PLAY',
#   'PLTK',
#   'POWW',
#   'PRST',
#   'QRVO',
#   'RRR',
#   'SBET',
#   'SCHL',
#   'SCPL',
#   'SJ',
#   'SLGG',
#   'SOHU',
#   'SRAD',
#   'STRA',
#   'STX',
#   'SWKS',
#   'TASK',
#   'TER',
#   'TTWO',
#   'UEIC',
#   'VNET',
#   'VS',
#   'WBD',
#   'WDC',
#   'WIMI',
#   'WYNN',
#   'XNET'},
#  'device': {'AAPL',
#   'ABNB',
#   'ABVC',
#   'ACIW',
#   'ACON',
#   'ADBE',
#   'ADEA',
#   'ADI',
#   'ADSK',
#   'ADTN',
#   'AEHL',
#   'AEHR',
#   'AEMD',
#   'AEY',
#   'AEYE',
#   'AFIB',
#   'AGFY',
#   'AGYS',
#   'AHCO',
#   'AIHS',
#   'AKAM',
#   'AKTS',
#   'AKYA',
#   'ALAR',
#   'ALBT',
#   'ALGN',
#   'ALPP',
#   'ALRM',
#   'ALTR',
#   'ALYA',
#   'AMAT',
#   'AMBA',
#   'AMD',
#   'AMKR',
#   'AMPG',
#   'AMSWA',
#   'AMWD',
#   'AMZN',
#   'ANGO',
#   'ANSS',
#   'ANY',
#   'AOUT',
#   'API',
#   'APP',
#   'APPS',
#   'APYX',
#   'ARBK',
#   'ARLP',
#   'ARQQ',
#   'ARRY',
#   'ARVL',
#   'ASML',
#   'ASUR',
#   'ATER',
#   'ATOM',
#   'ATRC',
#   'ATRI',
#   'ATRO',
#   'ATVI',
#   'AUID',
#   'AUR',
#   'AVDX',
#   'AVGO',
#   'AVGR',
#   'AVID',
#   'AVNW',
#   'AVPT',
#   'AVT',
#   'AXON',
#   'AXTI',
#   'AZPN',
#   'AZYO',
#   'BAND',
#   'BASE',
#   'BBLG',
#   'BCAN',
#   'BCPC',
#   'BEAT',
#   'BECN',
#   'BELFB',
#   'BIDU',
#   'BIMI',
#   'BITF',
#   'BJDX',
#   'BKYI',
#   'BLBX',
#   'BLIN',
#   'BLKB',
#   'BLNK',
#   'BLZE',
#   'BNGO',
#   'BOOM',
#   'BOXL',
#   'BRKR',
#   'BRQS',
#   'BRTX',
#   'BRZE',
#   'BSGM',
#   'BSQR',
#   'BSY',
#   'BTCY',
#   'BVS',
#   'BWEN',
#   'BYRN',
#   'CCCS',
#   'CCLD',
#   'CCLDP',
#   'CDNS',
#   'CDW',
#   'CEAD',
#   'CERT',
#   'CEVA',
#   'CFLT',
#   'CFRX',
#   'CG',
#   'CGBD',
#   'CGNT',
#   'CGNX',
#   'CGRN',
#   'CHEK',
#   'CHKP',
#   'CHTR',
#   'CJJD',
#   'CLAR',
#   'CLBT',
#   'CLEU',
#   'CLOV',
#   'CLPS',
#   'CLPT',
#   'CMAX',
#   'CMCO',
#   'CMTL',
#   'CNSL',
#   'CNXN',
#   'CODA',
#   'CODX',
#   'COHU',
#   'COMM',
#   'COMS',
#   'CONN',
#   'COSM',
#   'COST',
#   'CPOP',
#   'CPSI',
#   'CRCT',
#   'CREX',
#   'CRNC',
#   'CRSR',
#   'CRUS',
#   'CSCO',
#   'CSGP',
#   'CTKB',
#   'CTLP',
#   'CTSH',
#   'CTSO',
#   'CURI',
#   'CUTR',
#   'CVLT',
#   'CVRX',
#   'CXDO',
#   'CYN',
#   'DAKT',
#   'DALN',
#   'DATS',
#   'DCBO',
#   'DCFC',
#   'DCTH',
#   'DGII',
#   'DGLY',
#   'DH',
#   'DIOD',
#   'DISH',
#   'DLO',
#   'DLTR',
#   'DOGZ',
#   'DORM',
#   'DOX',
#   'DPRO',
#   'DRTT',
#   'DSP',
#   'DUO',
#   'DUOT',
#   'DXCM',
#   'DYNT',
#   'DZSI',
#   'EAR',
#   'EBIX',
#   'EBON',
#   'ECOR',
#   'ECX',
#   'EDAP',
#   'EDTK',
#   'EEFT',
#   'EGAN',
#   'EGIO',
#   'EKSO',
#   'ELYS',
#   'EM',
#   'EMBC',
#   'EMKR',
#   'ENPH',
#   'ENTG',
#   'EQIX',
#   'ERIC',
#   'ERII',
#   'ESLT',
#   'ESTA',
#   'EVBG',
#   'EVCM',
#   'EVGO',
#   'EVLV',
#   'EXFY',
#   'EXLS',
#   'EXPO',
#   'EXTR',
#   'EZGO',
#   'FARO',
#   'FAST',
#   'FCUV',
#   'FELE',
#   'FFIV',
#   'FIVE',
#   'FIVN',
#   'FLEX',
#   'FLGT',
#   'FLNC',
#   'FLYW',
#   'FORA',
#   'FORD',
#   'FORM',
#   'FPAY',
#   'FRHC',
#   'FROG',
#   'FRSH',
#   'FRSX',
#   'FTCI',
#   'FTDR',
#   'FTHM',
#   'FTNT',
#   'GAIA',
#   'GAN',
#   'GDEN',
#   'GDYN',
#   'GEHC',
#   'GEN',
#   'GEOS',
#   'GFAI',
#   'GFS',
#   'GMBL',
#   'GNSS',
#   'GOOG',
#   'GOOGL',
#   'GPRO',
#   'GRRR',
#   'GSM',
#   'GTLB',
#   'GTX',
#   'HALO',
#   'HBIO',
#   'HCAT',
#   'HCKT',
#   'HCTI',
#   'HEAR',
#   'HHS',
#   'HIMX',
#   'HLIT',
#   'HLMN',
#   'HLTH',
#   'HOLI',
#   'HOLO',
#   'HOLX',
#   'HON',
#   'HOTH',
#   'HSCS',
#   'HSDT',
#   'HSIC',
#   'HSTM',
#   'HTCR',
#   'HUBC',
#   'HUDI',
#   'HURC',
#   'HURN',
#   'HYFM',
#   'HYPR',
#   'IART',
#   'IAS',
#   'IBEX',
#   'ICCM',
#   'ICHR',
#   'ICLR',
#   'ICU',
#   'ICUI',
#   'IDAI',
#   'IDCC',
#   'IDN',
#   'IDXX',
#   'IFBD',
#   'IHRT',
#   'IIIV',
#   'IINN',
#   'IMMR',
#   'IMXI',
#   'INDI',
#   'INFN',
#   'INGN',
#   'INO',
#   'INPX',
#   'INSE',
#   'INSG',
#   'INTA',
#   'INTC',
#   'INTR',
#   'INTU',
#   'INTZ',
#   'INVO',
#   'INVZ',
#   'IRDM',
#   'IRIX',
#   'ITRI',
#   'ITRN',
#   'IVDA',
#   'JAMF',
#   'JD',
#   'JFIN',
#   'JKHY',
#   'JXJT',
#   'KALU',
#   'KBNT',
#   'KC',
#   'KERN',
#   'KIDS',
#   'KITT',
#   'KLAC',
#   'KLIC',
#   'KLTR',
#   'KOSS',
#   'KRMD',
#   'KSCP',
#   'KTCC',
#   'LAB',
#   'LAZR',
#   'LBRDA',
#   'LBRDK',
#   'LEDS',
#   'LFLY',
#   'LFMD',
#   'LFUS',
#   'LGMK',
#   'LIDR',
#   'LIVN',
#   'LKCO',
#   'LNSR',
#   'LNTH',
#   'LNW',
#   'LOGI',
#   'LPTH',
#   'LSAK',
#   'LSXMA',
#   'LSXMK',
#   'LUCD',
#   'LUNG',
#   'LVOX',
#   'LWLG',
#   'LX',
#   'MANH',
#   'MAPS',
#   'MARK',
#   'MASS',
#   'MBOT',
#   'MCHP',
#   'MCLD',
#   'MDGS',
#   'MDRX',
#   'MEDP',
#   'META',
#   'MGIC',
#   'MHUA',
#   'MINM',
#   'MITK',
#   'MKSI',
#   'MKTW',
#   'MKUL',
#   'MLGO',
#   'MMAT',
#   'MNDY',
#   'MNKD',
#   'MOB',
#   'MOBQ',
#   'MORN',
#   'MOTS',
#   'MOVE',
#   'MPWR',
#   'MRIN',
#   'MSFT',
#   'MSGM',
#   'MSTR',
#   'MTEK',
#   'MTLS',
#   'MU',
#   'MVBF',
#   'MVIS',
#   'MVLA',
#   'MXCT',
#   'MXL',
#   'NAAS',
#   'NATI',
#   'NAUT',
#   'NCNO',
#   'NCPL',
#   'NDSN',
#   'NEGG',
#   'NEOG',
#   'NEON',
#   'NFLX',
#   'NGMS',
#   'NMFC',
#   'NMRD',
#   'NN',
#   'NNBR',
#   'NNDM',
#   'NNOX',
#   'NOGN',
#   'NOTV',
#   'NPCE',
#   'NSIT',
#   'NSPR',
#   'NSSC',
#   'NSTG',
#   'NTAP',
#   'NTCT',
#   'NTES',
#   'NTGR',
#   'NTNX',
#   'NTRA',
#   'NTWK',
#   'NURO',
#   'NUVA',
#   'NUWE',
#   'NVCR',
#   'NVDA',
#   'NVEC',
#   'NVEI',
#   'NVIV',
#   'NVOS',
#   'NXGN',
#   'NXL',
#   'NXPL',
#   'OBIO',
#   'OBLG',
#   'OCG',
#   'OCSL',
#   'OFIX',
#   'OKTA',
#   'OLED',
#   'OLK',
#   'OLLI',
#   'OM',
#   'OMCL',
#   'ONDS',
#   'ONVO',
#   'OPRA',
#   'OPTN',
#   'OSIS',
#   'OSPN',
#   'OSS',
#   'OST',
#   'OSUR',
#   'OTEX',
#   'OTMO',
#   'OXSQ',
#   'PALT',
#   'PANW',
#   'PAVM',
#   'PAYX',
#   'PBTS',
#   'PCTI',
#   'PCTY',
#   'PDCO',
#   'PDFS',
#   'PEGA',
#   'PEGY',
#   'PERI',
#   'PETV',
#   'PFSW',
#   'PGY',
#   'PHUN',
#   'PI',
#   'PLPC',
#   'PODD',
#   'POET',
#   'POWI',
#   'PRCH',
#   'PRDO',
#   'PRE',
#   'PRGS',
#   'PROF',
#   'PRSO',
#   'PRST',
#   'PRTH',
#   'PSEC',
#   'PTC',
#   'PTEN',
#   'PTPI',
#   'PUBM',
#   'PWFL',
#   'QCOM',
#   'QH',
#   'QLGN',
#   'QMCO',
#   'QRVO',
#   'QUBT',
#   'QUIK',
#   'RBBN',
#   'RBCAA',
#   'RCON',
#   'RDVT',
#   'RDWR',
#   'REFR',
#   'REKR',
#   'RENT',
#   'RFIL',
#   'RGEN',
#   'RGTI',
#   'RILY',
#   'RILYP',
#   'RMBS',
#   'RMNI',
#   'RNXT',
#   'ROKU',
#   'ROP',
#   'RPAY',
#   'RPD',
#   'RPID',
#   'RSLS',
#   'RTC',
#   'RVSN',
#   'RVYL',
#   'RWAY',
#   'RWLK',
#   'RXST',
#   'SABR',
#   'SANM',
#   'SASI',
#   'SATS',
#   'SBGI',
#   'SBIG',
#   'SCKT',
#   'SCOR',
#   'SCPH',
#   'SCSC',
#   'SDGR',
#   'SEAT',
#   'SECO',
#   'SEDG',
#   'SEER',
#   'SGH',
#   'SGHT',
#   'SIBN',
#   'SIDU',
#   'SIFY',
#   'SILK',
#   'SIMO',
#   'SINT',
#   'SIRI',
#   'SMCI',
#   'SMSI',
#   'SMTC',
#   'SNCE',
#   'SNCR',
#   'SNPO',
#   'SNPS',
#   'SNT',
#   'SOBR',
#   'SOHU',
#   'SONM',
#   'SOPA',
#   'SOPH',
#   'SPCB',
#   'SPLK',
#   'SPNS',
#   'SPOK',
#   'SPT',
#   'SPWH',
#   'SPWR',
#   'SRAD',
#   'SRDX',
#   'SRTS',
#   'SSNC',
#   'SSP',
#   'SSTI',
#   'SSYS',
#   'STAA',
#   'STCN',
#   'STER',
#   'STGW',
#   'STIX',
#   'STNE',
#   'STSS',
#   'SURG',
#   'SWAV',
#   'SWKH',
#   'SWKS',
#   'SY',
#   'SYM',
#   'SYNA',
#   'SYNH',
#   'SYTA',
#   'TAOP',
#   'TBLA',
#   'TCMD',
#   'TCPC',
#   'TEAM',
#   'TENB',
#   'TER',
#   'TGAN',
#   'THRM',
#   'TIO',
#   'TKLF',
#   'TMCI',
#   'TMPO',
#   'TMUS',
#   'TNDM',
#   'TNON',
#   'TRHC',
#   'TRMB',
#   'TRMR',
#   'TRUE',
#   'TSCO',
#   'TSEM',
#   'TTD',
#   'TTWO',
#   'TWKS',
#   'TXG',
#   'UCL',
#   'UCTT',
#   'UEIC',
#   'UMBF',
#   'UPBD',
#   'UPLD',
#   'UPWK',
#   'UTMD',
#   'UTRS',
#   'VANI',
#   'VC',
#   'VCEL',
#   'VECO',
#   'VERO',
#   'VERX',
#   'VIAV',
#   'VIEW',
#   'VIOT',
#   'VMD',
#   'VMEO',
#   'VOD',
#   'VRAR',
#   'VREX',
#   'VRNS',
#   'VRRM',
#   'VS',
#   'VSAT',
#   'VTSI',
#   'VUZI',
#   'WATT',
#   'WAVD',
#   'WDC',
#   'WDFC',
#   'WETG',
#   'WFRD',
#   'WIMI',
#   'WISA',
#   'WKEY',
#   'WKME',
#   'WLDS',
#   'WRAP',
#   'WTW',
#   'WWD',
#   'XAIR',
#   'XELA',
#   'XMTR',
#   'XNET',
#   'XPEL',
#   'XRX',
#   'YI',
#   'YJ',
#   'Z',
#   'ZBRA',
#   'ZG',
#   'ZI',
#   'ZIMV',
#   'ZLAB',
#   'ZM',
#   'ZS',
#   'ZYXI'},
#  'accessory': {'AAPL',
#   'AFIB',
#   'AFRM',
#   'AOUT',
#   'APYX',
#   'AREB',
#   'ARHS',
#   'ASO',
#   'BGFV',
#   'BIOL',
#   'BOXL',
#   'BYRN',
#   'CAR',
#   'CASY',
#   'CGRN',
#   'CLAR',
#   'COLM',
#   'COMM',
#   'CONN',
#   'CRCT',
#   'CREX',
#   'CROX',
#   'CRSR',
#   'CTRN',
#   'DBGI',
#   'DFLI',
#   'DLTH',
#   'DLTR',
#   'DRRX',
#   'DRVN',
#   'ENPH',
#   'EYE',
#   'FAST',
#   'FGI',
#   'FIVE',
#   'FLGC',
#   'FNKO',
#   'FORD',
#   'FOSL',
#   'FPAY',
#   'FSTR',
#   'GIII',
#   'GNLN',
#   'GNTX',
#   'GPRO',
#   'GRWG',
#   'HAS',
#   'HBIO',
#   'HEAR',
#   'HELE',
#   'HFFG',
#   'HIBB',
#   'HITI',
#   'HLMN',
#   'HURC',
#   'INGN',
#   'IPGP',
#   'IRBT',
#   'IRDM',
#   'JAKK',
#   'JD',
#   'JOAN',
#   'KOSS',
#   'LAKE',
#   'LAZY',
#   'LE',
#   'LECO',
#   'LFUS',
#   'LKQ',
#   'LOGI',
#   'LULU',
#   'LVLU',
#   'MAT',
#   'MCFT',
#   'MMSI',
#   'MSFT',
#   'MXCT',
#   'NIU',
#   'NPCE',
#   'OFLX',
#   'ONEW',
#   'ORLY',
#   'OSIS',
#   'PATK',
#   'PFSW',
#   'PIK',
#   'PLCE',
#   'POWW',
#   'PRTS',
#   'QIPT',
#   'QRTEA',
#   'QRTEP',
#   'RENT',
#   'RILY',
#   'RILYP',
#   'RIVN',
#   'ROCK',
#   'ROKU',
#   'ROST',
#   'SCVL',
#   'SECO',
#   'SFIX',
#   'SGC',
#   'SHOO',
#   'SHYF',
#   'SMCI',
#   'SONM',
#   'SONO',
#   'SOPA',
#   'SPWH',
#   'TANH',
#   'TBLT',
#   'TDUP',
#   'TMUS',
#   'UEIC',
#   'UFPI',
#   'ULBI',
#   'ULTA',
#   'UPBD',
#   'URBN',
#   'UTMD',
#   'UTME',
#   'VINO',
#   'VLCN',
#   'VRA',
#   'VSEC',
#   'VTSI',
#   'WEYS',
#   'WINA',
#   'XPEL',
#   'XPON',
#   'ZBRA',
#   'ZUMZ'},
#  'media': {'AAPL',
#   'ADBE',
#   'ADD',
#   'ADEA',
#   'ADSK',
#   'ADTH',
#   'ADV',
#   'AEHL',
#   'AEI',
#   'AEY',
#   'AEYE',
#   'AKAM',
#   'ALPP',
#   'ALRM',
#   'AMBA',
#   'AMCX',
#   'AMZN',
#   'ANGH',
#   'API',
#   'APP',
#   'APPS',
#   'ARHS',
#   'ATNI',
#   'ATVI',
#   'AVDX',
#   'AVID',
#   'AXON',
#   'BASE',
#   'BBGI',
#   'BEEM',
#   'BIDU',
#   'BILI',
#   'BLBX',
#   'BLFS',
#   'BLZE',
#   'BRAG',
#   'BTWN',
#   'BZFD',
#   'CCOI',
#   'CDW',
#   'CG',
#   'CHDN',
#   'CHTR',
#   'CMCSA',
#   'CMLS',
#   'CMTL',
#   'CNSL',
#   'CNVS',
#   'CNXC',
#   'CNXN',
#   'COMM',
#   'COMS',
#   'CONN',
#   'CPOP',
#   'CREX',
#   'CSSE',
#   'CSSEP',
#   'CTSH',
#   'CURI',
#   'CXDO',
#   'CZR',
#   'DAKT',
#   'DALN',
#   'DBX',
#   'DGLY',
#   'DISH',
#   'DLPN',
#   'DOX',
#   'DOYU',
#   'DZSI',
#   'EGHT',
#   'EGIO',
#   'EGLX',
#   'EH',
#   'ERIC',
#   'ETSY',
#   'EVBG',
#   'EXPE',
#   'EXPI',
#   'FA',
#   'FAZE',
#   'FIVE',
#   'FIVN',
#   'FLNT',
#   'FNKO',
#   'FOX',
#   'FOXA',
#   'FTHM',
#   'FWONA',
#   'FWONK',
#   'FYBR',
#   'GAIA',
#   'GAME',
#   'GDYN',
#   'GECC',
#   'GEHC',
#   'GEN',
#   'GLAD',
#   'GNSS',
#   'GPRO',
#   'GROM',
#   'GRRR',
#   'GRWG',
#   'GSMG',
#   'HEAR',
#   'HLIT',
#   'HOFV',
#   'HON',
#   'HYFM',
#   'IAC',
#   'IAS',
#   'IBEX',
#   'ICLK',
#   'IDAI',
#   'IDCC',
#   'IHRT',
#   'IMTE',
#   'INPX',
#   'INVE',
#   'IPA',
#   'IPW',
#   'IQ',
#   'IVDA',
#   'JG',
#   'JZ',
#   'KC',
#   'KLTR',
#   'KRKR',
#   'LBRDA',
#   'LBRDK',
#   'LBTYA',
#   'LBTYK',
#   'LEE',
#   'LILA',
#   'LILAK',
#   'LIQT',
#   'LITE',
#   'LNW',
#   'LOGI',
#   'LSCC',
#   'LSXMA',
#   'LSXMK',
#   'LTRY',
#   'LUCY',
#   'LVLU',
#   'LVO',
#   'LWLG',
#   'MARK',
#   'META',
#   'MFIC',
#   'MGNI',
#   'MKTW',
#   'MMV',
#   'MOMO',
#   'MSGM',
#   'MTEK',
#   'NEGG',
#   'NEOG',
#   'NEON',
#   'NFLX',
#   'NMFC',
#   'NOVT',
#   'NSSC',
#   'NTAP',
#   'NTNX',
#   'NWS',
#   'NWSA',
#   'NXST',
#   'NXTP',
#   'OB',
#   'OBLG',
#   'OCSL',
#   'OSPN',
#   'OXSQ',
#   'PALT',
#   'PANW',
#   'PARA',
#   'PARAA',
#   'PARAP',
#   'PCTY',
#   'PEGA',
#   'PERI',
#   'PHUN',
#   'PRCH',
#   'PRFT',
#   'PRPO',
#   'PRSO',
#   'PSEC',
#   'PTMN',
#   'PUBM',
#   'PWP',
#   'QMCO',
#   'QRTEA',
#   'QRTEP',
#   'RCON',
#   'RCRT',
#   'RELI',
#   'RICK',
#   'ROKU',
#   'ROOT',
#   'RPD',
#   'RSVR',
#   'RTC',
#   'RUM',
#   'RUN',
#   'SALM',
#   'SBET',
#   'SBGI',
#   'SCHL',
#   'SCOR',
#   'SCSC',
#   'SGH',
#   'SHEN',
#   'SHOO',
#   'SIRI',
#   'SLGG',
#   'SMTC',
#   'SNPO',
#   'SNT',
#   'SOHU',
#   'SP',
#   'SPT',
#   'SRAD',
#   'SSP',
#   'STBX',
#   'STEP',
#   'STER',
#   'STGW',
#   'STRA',
#   'STX',
#   'SY',
#   'SYNA',
#   'TAOP',
#   'TASK',
#   'TBLA',
#   'THRY',
#   'TKNO',
#   'TRKA',
#   'TRMB',
#   'TSAT',
#   'TTD',
#   'TTEC',
#   'TTGT',
#   'TTWO',
#   'TZOO',
#   'UEIC',
#   'UONE',
#   'UONEK',
#   'UPLD',
#   'URBN',
#   'VERB',
#   'VERI',
#   'VIRC',
#   'VISL',
#   'VMEO',
#   'VQS',
#   'VRAR',
#   'VS',
#   'VTRU',
#   'WB',
#   'WBD',
#   'WDAY',
#   'WDC',
#   'WIMI',
#   'WMG',
#   'XNET',
#   'YY',
#   'Z',
#   'ZCMD',
#   'ZD',
#   'ZFOX',
#   'ZG',
#   'ZI',
#   'ZM',
#   'ZS'},
#  'vehicle': {'ABCB',
#   'ACNB',
#   'ACVA',
#   'AIHS',
#   'AOSL',
#   'ARBE',
#   'ARCB',
#   'ARVL',
#   'ASTE',
#   'ASTI',
#   'ATLO',
#   'ATSG',
#   'AUR',
#   'AVAV',
#   'AXTI',
#   'AYRO',
#   'AZ',
#   'BANR',
#   'BEEM',
#   'BIDU',
#   'BLDP',
#   'BLNK',
#   'CACC',
#   'CAR',
#   'CBAT',
#   'CBSH',
#   'CCB',
#   'CECO',
#   'CENN',
#   'CFFN',
#   'CGNX',
#   'CGRN',
#   'CHCO',
#   'CLAR',
#   'CLNE',
#   'CNDT',
#   'CPRT',
#   'CPSS',
#   'CRGE',
#   'CRMT',
#   'CTLP',
#   'CYN',
#   'DCFC',
#   'DFLI',
#   'DHIL',
#   'DOOO',
#   'DORM',
#   'DPRO',
#   'DRS',
#   'DRVN',
#   'ECX',
#   'EH',
#   'ELBM',
#   'ENPH',
#   'ESLT',
#   'EVGO',
#   'EVTV',
#   'EXPO',
#   'EZFL',
#   'FA',
#   'FFBC',
#   'FFIE',
#   'FISI',
#   'FITB',
#   'FITBO',
#   'FITBP',
#   'FMAO',
#   'FNCB',
#   'FNLC',
#   'FRSX',
#   'FUV',
#   'GCBC',
#   'GFAI',
#   'GGR',
#   'GNTX',
#   'GOEV',
#   'GP',
#   'GRRR',
#   'GSHD',
#   'GTEC',
#   'GTX',
#   'HAS',
#   'HBAN',
#   'HBANM',
#   'HBANP',
#   'HCCI',
#   'HOLO',
#   'HTLF',
#   'HTZ',
#   'HYZN',
#   'IDEX',
#   'INDI',
#   'INSG',
#   'INVZ',
#   'IPWR',
#   'IRDM',
#   'ISUN',
#   'ITRN',
#   'JAKK',
#   'JFBR',
#   'JZXN',
#   'KALU',
#   'KITT',
#   'KNDI',
#   'KOPN',
#   'KSCP',
#   'LAZR',
#   'LAZY',
#   'LCID',
#   'LFUS',
#   'LI',
#   'LIDR',
#   'LKQ',
#   'LSXMA',
#   'LSXMK',
#   'LYFT',
#   'MAT',
#   'MBLY',
#   'MBWM',
#   'MDGS',
#   'MELI',
#   'MSBI',
#   'MTEK',
#   'MULN',
#   'MVST',
#   'NAAS',
#   'NKLA',
#   'NTWK',
#   'NVDA',
#   'NVTS',
#   'NVVE',
#   'NWFL',
#   'NWTN',
#   'ON',
#   'OPAL',
#   'OSBC',
#   'OSIS',
#   'OTTR',
#   'OXLC',
#   'OXLCM',
#   'OZK',
#   'OZKAP',
#   'PATK',
#   'PCAR',
#   'PCTI',
#   'PDFS',
#   'PEV',
#   'PLUG',
#   'POWI',
#   'PSNY',
#   'PWFL',
#   'QCRH',
#   'RAIL',
#   'RAYA',
#   'REE',
#   'REKR',
#   'RIVN',
#   'RKLB',
#   'RMBL',
#   'RUSHA',
#   'RVSN',
#   'SAFT',
#   'SCHN',
#   'SEDG',
#   'SFT',
#   'SGML',
#   'SHLS',
#   'SHYF',
#   'SIRI',
#   'SLDP',
#   'SOLO',
#   'SP',
#   'SPCB',
#   'SPFI',
#   'SPI',
#   'STER',
#   'SWVL',
#   'SYPR',
#   'SYTA',
#   'TANH',
#   'TGAN',
#   'THRM',
#   'TMC',
#   'TOWN',
#   'TRDA',
#   'TRMB',
#   'TRUE',
#   'TSLA',
#   'ULBI',
#   'UXIN',
#   'VC',
#   'VLCN',
#   'VRM',
#   'VSEC',
#   'VVPR',
#   'WKHS',
#   'WSBC',
#   'WSBCP',
#   'XOS',
#   'XPON',
#   'ZBRA'},
#  'estate': {'ABCB',
#   'ACNB',
#   'AEI',
#   'AFCG',
#   'AGBA',
#   'AGNC',
#   'AGNCL',
#   'AGNCM',
#   'AGNCN',
#   'AGNCO',
#   'AGNCP',
#   'AGRI',
#   'ALBT',
#   'ALRS',
#   'ALTI',
#   'AMAL',
#   'AMNB',
#   'AMWD',
#   'APPF',
#   'AROW',
#   'ARTNA',
#   'ATLO',
#   'AVDX',
#   'BANF',
#   'BANR',
#   'BATRA',
#   'BATRK',
#   'BCBP',
#   'BCML',
#   'BFC',
#   'BFIN',
#   'BFST',
#   'BLFY',
#   'BMRC',
#   'BNMV',
#   'BOKF',
#   'BPOP',
#   'BPRN',
#   'BPYPO',
#   'BPYPP',
#   'BRKL',
#   'BSRR',
#   'BSVN',
#   'BUSE',
#   'BWB',
#   'BWMN',
#   'CAC',
#   'CARE',
#   'CARV',
#   'CASS',
#   'CATY',
#   'CBAN',
#   'CBNK',
#   'CBSH',
#   'CCB',
#   'CCBG',
#   'CCNE',
#   'CFB',
#   'CFFN',
#   'CG',
#   'CGBD',
#   'CHCI',
#   'CHCO',
#   'CIGI',
#   'CLBK',
#   'CNOB',
#   'CNOBP',
#   'COFS',
#   'COLB',
#   'CPOP',
#   'CSGP',
#   'CSTR',
#   'CSWC',
#   'CTBI',
#   'CVBF',
#   'CVLY',
#   'CZFS',
#   'CZNC',
#   'DCOM',
#   'DCOMP',
#   'DH',
#   'DHC',
#   'DOCU',
#   'DUO',
#   'EBC',
#   'EBTC',
#   'ECBK',
#   'EFSC',
#   'ENSG',
#   'ESQ',
#   'ESSA',
#   'EWBC',
#   'EXPI',
#   'FBIZ',
#   'FBMS',
#   'FBNC',
#   'FCBC',
#   'FFBC',
#   'FFIC',
#   'FFIN',
#   'FGBI',
#   'FHB',
#   'FIBK',
#   'FISI',
#   'FITB',
#   'FITBO',
#   'FITBP',
#   'FLIC',
#   'FMAO',
#   'FNCB',
#   'FNLC',
#   'FRME',
#   'FRPH',
#   'FRST',
#   'FSBC',
#   'FSEA',
#   'FTHM',
#   'FULT',
#   'FULTP',
#   'FVCB',
#   'GABC',
#   'GCBC',
#   'GIPR',
#   'GLPI',
#   'GOOD',
#   'GRNQ',
#   'GSBC',
#   'HAFC',
#   'HBAN',
#   'HBANM',
#   'HBANP',
#   'HBNC',
#   'HCDI',
#   'HFWA',
#   'HIFS',
#   'HLNE',
#   'HONE',
#   'HOPE',
#   'HST',
#   'HTBK',
#   'HTIA',
#   'HTIBP',
#   'HTLF',
#   'HWBK',
#   'HYW',
#   'IBOC',
#   'IDAI',
#   'IDEX',
#   'IEP',
#   'ILPT',
#   'INDB',
#   'ISPO',
#   'JD',
#   'JG',
#   'JMSB',
#   'KRNY',
#   'LANDO',
#   'LBAI',
#   'LBC',
#   'LKFN',
#   'LNKB',
#   'LPLA',
#   'LZ',
#   'MBCN',
#   'MBWM',
#   'MCBS',
#   'MELI',
#   'MNSB',
#   'MOFG',
#   'MRBK',
#   'MSBI',
#   'MTTR',
#   'MVBF',
#   'NBN',
#   'NBTB',
#   'NCNO',
#   'NECB',
#   'NFBK',
#   'NKSH',
#   'NRIM',
#   'NTRS',
#   'NTRSO',
#   'NUTX',
#   'NWFL',
#   'NWLI',
#   'NWS',
#   'NWSA',
#   'NXST',
#   'NYMT',
#   'NYMTM',
#   'NYMTN',
#   'OBLG',
#   'OBT',
#   'OCFC',
#   'OCSL',
#   'OMAB',
#   'ONB',
#   'ONBPO',
#   'ONBPP',
#   'OPBK',
#   'OPEN',
#   'OPI',
#   'OSBC',
#   'OZK',
#   'OZKAP',
#   'PACW',
#   'PACWP',
#   'PAX',
#   'PBFS',
#   'PCB',
#   'PCH',
#   'PEBO',
#   'PFC',
#   'PFG',
#   'PFIS',
#   'PGC',
#   'PGY',
#   'PHUN',
#   'PKBK',
#   'PNFP',
#   'PNFPP',
#   'PPBI',
#   'PSEC',
#   'PTMN',
#   'PVBC',
#   'PWOD',
#   'QCRH',
#   'RBB',
#   'RBCAA',
#   'RDFN',
#   'REAX',
#   'REFI',
#   'REG',
#   'RILY',
#   'RILYP',
#   'RMR',
#   'RPD',
#   'RRBI',
#   'RTL',
#   'RTLPO',
#   'RTLPP',
#   'SASR',
#   'SBAC',
#   'SBGI',
#   'SBRA',
#   'SBSI',
#   'SBT',
#   'SEVN',
#   'SFNC',
#   'SFST',
#   'SHBI',
#   'SMBC',
#   'SMBK',
#   'SOHU',
#   'SPFI',
#   'SPOK',
#   'SQFT',
#   'SRCE',
#   'SSB',
#   'SSBK',
#   'STBA',
#   'STBX',
#   'STEP',
#   'STRR',
#   'STRS',
#   'SVC',
#   'SYBT',
#   'TCBI',
#   'TCBIO',
#   'TCBK',
#   'TCBX',
#   'TFIN',
#   'TFSL',
#   'THFF',
#   'TOWN',
#   'TPG',
#   'TREE',
#   'TRMK',
#   'TROO',
#   'TRST',
#   'UBFO',
#   'UBSI',
#   'UCBI',
#   'UCBIO',
#   'UMBF',
#   'UNIT',
#   'USCB',
#   'VABK',
#   'VCSA',
#   'VIEW',
#   'VINO',
#   'VINP',
#   'VLY',
#   'VLYPO',
#   'VLYPP',
#   'WABC',
#   'WAFD',
#   'WAFDP',
#   'WASH',
#   'WEN',
#   'WIMI',
#   'WMPN',
#   'WNEB',
#   'WSBC',
#   'WSBCP',
#   'WSBF',
#   'WSFS',
#   'WTBA',
#   'WTFC',
#   'WTFCM',
#   'WTFCP',
#   'XP',
#   'Z',
#   'ZG',
#   'ZI',
#   'ZION'},
#  'ai': {'ABSI',
#   'AGIL',
#   'AIMD',
#   'ALLT',
#   'ALTR',
#   'ALYA',
#   'AMBA',
#   'AMD',
#   'AMST',
#   'API',
#   'APLD',
#   'APPN',
#   'ATER',
#   'AUUD',
#   'BL',
#   'BLKB',
#   'BLZE',
#   'BTAI',
#   'CAR',
#   'CCCS',
#   'CCLD',
#   'CCLDP',
#   'CD',
#   'CEVA',
#   'CGNT',
#   'CNXA',
#   'COMS',
#   'CRNC',
#   'CRVL',
#   'CRWD',
#   'CTSH',
#   'CYN',
#   'DCBO',
#   'DH',
#   'DOMO',
#   'DOX',
#   'DRS',
#   'DSP',
#   'DUOT',
#   'ESLT',
#   'EVLV',
#   'EXAI',
#   'EXLS',
#   'FLNC',
#   'FROG',
#   'FTHM',
#   'FWRG',
#   'GFAI',
#   'GLG',
#   'GLMD',
#   'GOOG',
#   'GOOGL',
#   'GRRR',
#   'HCTI',
#   'HIMX',
#   'ICFI',
#   'ICLK',
#   'IDAI',
#   'IDCC',
#   'IFBD',
#   'INPX',
#   'INTA',
#   'INTC',
#   'INTZ',
#   'IRDM',
#   'IVDA',
#   'JG',
#   'KERN',
#   'KFRC',
#   'KRBP',
#   'KTOS',
#   'LNTH',
#   'LTRN',
#   'LVOX',
#   'MARK',
#   'MCHX',
#   'MCLD',
#   'MITK',
#   'MLGO',
#   'MOBQ',
#   'MRAI',
#   'MTEK',
#   'MYSZ',
#   'NCNO',
#   'NDAQ',
#   'NICE',
#   'NNOX',
#   'NSIT',
#   'NVDA',
#   'NVEI',
#   'OABI',
#   'OESX',
#   'OPGN',
#   'OTEX',
#   'OTMO',
#   'OTRK',
#   'PANW',
#   'PERI',
#   'PGY',
#   'POAI',
#   'PRFT',
#   'PRST',
#   'PWFL',
#   'QCOM',
#   'QFIN',
#   'QMCO',
#   'RCM',
#   'RDVT',
#   'RDWR',
#   'REKR',
#   'RNLX',
#   'RPD',
#   'RTC',
#   'SABR',
#   'SMCI',
#   'SNEX',
#   'SOUN',
#   'SPT',
#   'SSNC',
#   'STGW',
#   'STIX',
#   'STRA',
#   'SYNA',
#   'TASK',
#   'TLS',
#   'TRKA',
#   'TRMB',
#   'TROO',
#   'TTEC',
#   'TWKS',
#   'UPST',
#   'VERI',
#   'VOD',
#   'VRME',
#   'VRNS',
#   'VRNT',
#   'WETG',
#   'WGS',
#   'WIMI',
#   'WKME',
#   'ZBRA',
#   'ZENV',
#   'ZFOX',
#   'ZI'},
#  'oil': {'ACB',
#   'ACDC',
#   'ALTO',
#   'AMTX',
#   'ANDE',
#   'APA',
#   'ARCB',
#   'ARCC',
#   'ARKO',
#   'ARLP',
#   'ASTE',
#   'AZPN',
#   'BKR',
#   'BOOM',
#   'BRY',
#   'BWEN',
#   'CG',
#   'CHK',
#   'CHRD',
#   'CHSCM',
#   'CHSCP',
#   'CHX',
#   'CLMT',
#   'CLVR',
#   'CMTL',
#   'COCO',
#   'CPLP',
#   'CPSH',
#   'CREG',
#   'CRNT',
#   'CSWC',
#   'CTRM',
#   'CZFS',
#   'DMLP',
#   'DRVN',
#   'DXPE',
#   'EPSN',
#   'ESOA',
#   'EVRG',
#   'FANG',
#   'FAST',
#   'FELE',
#   'FFIN',
#   'FIP',
#   'FSTR',
#   'GEOS',
#   'GLDD',
#   'GPRE',
#   'GRIN',
#   'GURE',
#   'HAYN',
#   'HCCI',
#   'HFFG',
#   'HPK',
#   'HTOO',
#   'HUDI',
#   'IMPP',
#   'INCR',
#   'IOSP',
#   'IPGP',
#   'KLXE',
#   'LAKE',
#   'LKQ',
#   'MARPS',
#   'MFIC',
#   'MMLP',
#   'MTRX',
#   'NWPX',
#   'ORLY',
#   'PAA',
#   'PAGP',
#   'PCTI',
#   'PNRG',
#   'POWL',
#   'PSEC',
#   'PTEN',
#   'PXS',
#   'PYR',
#   'QRHC',
#   'RCON',
#   'SANM',
#   'SASI',
#   'SCWO',
#   'SND',
#   'SNT',
#   'SYPR',
#   'TCPC',
#   'TKLF',
#   'TOPS',
#   'TRMD',
#   'TSAT',
#   'TUSK',
#   'USAP',
#   'USEG',
#   'USLM',
#   'VTNR',
#   'WFRD',
#   'WPRT',
#   'XEL',
#   'YTEN',
#   'ZKIN'},
#  'energy': {'ACB',
#   'ACDC',
#   'ADN',
#   'AEIS',
#   'AEP',
#   'AHG',
#   'ALTO',
#   'AMTX',
#   'ANDE',
#   'APA',
#   'ARCC',
#   'ARKO',
#   'ARLP',
#   'ASTE',
#   'ATSG',
#   'AY',
#   'AZ',
#   'AZPN',
#   'BKR',
#   'BLDP',
#   'BOOM',
#   'BRY',
#   'BWEN',
#   'CAR',
#   'CASS',
#   'CASY',
#   'CBUS',
#   'CECO',
#   'CEG',
#   'CG',
#   'CGRN',
#   'CHK',
#   'CHRD',
#   'CHSCM',
#   'CHSCP',
#   'CHX',
#   'CLMT',
#   'CLNE',
#   'CLVR',
#   'CMTL',
#   'COCO',
#   'COST',
#   'CPLP',
#   'CPSH',
#   'CREG',
#   'CRNT',
#   'CSWC',
#   'CTRM',
#   'CZFS',
#   'DCFC',
#   'DMLP',
#   'DORM',
#   'DRVN',
#   'DXPE',
#   'ENG',
#   'ENTG',
#   'EPSN',
#   'ERII',
#   'ESOA',
#   'EVRG',
#   'EXC',
#   'EZFL',
#   'FANG',
#   'FAST',
#   'FCBC',
#   'FCEL',
#   'FELE',
#   'FFIN',
#   'FIP',
#   'FSTR',
#   'FTEK',
#   'GEOS',
#   'GEVO',
#   'GGR',
#   'GIFI',
#   'GLDD',
#   'GLNG',
#   'GPP',
#   'GPRE',
#   'GREE',
#   'GRIN',
#   'GURE',
#   'HAYN',
#   'HCCI',
#   'HDSN',
#   'HFFG',
#   'HNRG',
#   'HON',
#   'HPK',
#   'HTOO',
#   'HUDI',
#   'HYZN',
#   'ICHR',
#   'IDXX',
#   'IMKTA',
#   'IMPP',
#   'INCR',
#   'IOSP',
#   'IPGP',
#   'ITRN',
#   'KLXE',
#   'LAKE',
#   'LECO',
#   'LFUS',
#   'LIQT',
#   'LITE',
#   'LKQ',
#   'LNT',
#   'LSXMA',
#   'LSXMK',
#   'LTBR',
#   'MARPS',
#   'MASI',
#   'MASS',
#   'MFIC',
#   'MGEE',
#   'MKSI',
#   'MMLP',
#   'MNST',
#   'MNTK',
#   'MTRX',
#   'MYRG',
#   'NDSN',
#   'NEXT',
#   'NFE',
#   'NKLA',
#   'NNBR',
#   'NWPX',
#   'OFLX',
#   'OPAL',
#   'ORLY',
#   'OTMO',
#   'OTTR',
#   'PAA',
#   'PAGP',
#   'PATK',
#   'PCTI',
#   'PLUG',
#   'PNRG',
#   'POLA',
#   'POWL',
#   'PSEC',
#   'PTEN',
#   'PXS',
#   'PYR',
#   'QRHC',
#   'RCON',
#   'RUSHA',
#   'SANM',
#   'SASI',
#   'SCWO',
#   'SIRI',
#   'SLNG',
#   'SMPL',
#   'SND',
#   'SNT',
#   'SPTN',
#   'SYPR',
#   'TCPC',
#   'TIO',
#   'TKLF',
#   'TOPS',
#   'TRMD',
#   'TSAT',
#   'TTEK',
#   'TUSK',
#   'UCTT',
#   'USAP',
#   'USEG',
#   'USLM',
#   'VIA',
#   'VIASP',
#   'VIOT',
#   'WFRD',
#   'WPRT',
#   'WWD',
#   'XEL',
#   'YTEN',
#   'ZKIN'},
#  'travel': {'ACGL',
#   'ACGLN',
#   'ACGLO',
#   'AFRM',
#   'ALGT',
#   'AUID',
#   'BASE',
#   'BKNG',
#   'BRSH',
#   'CAR',
#   'CCRN',
#   'CNXC',
#   'COST',
#   'CTSH',
#   'DLO',
#   'DOYU',
#   'DRCT',
#   'EBIX',
#   'EVBG',
#   'EXFY',
#   'EXPE',
#   'FANH',
#   'FLGC',
#   'FLYW',
#   'HA',
#   'HELE',
#   'HUIZ',
#   'IAC',
#   'IBEX',
#   'IDAI',
#   'INTR',
#   'ISPO',
#   'LIND',
#   'LUXH',
#   'MMYT',
#   'MOND',
#   'MTTR',
#   'NSIT',
#   'NWL',
#   'NXTP',
#   'PAYS',
#   'PI',
#   'RAVE',
#   'RYAAY',
#   'SABR',
#   'SIRI',
#   'SNY',
#   'SWVL',
#   'TCOM',
#   'TGL',
#   'TOUR',
#   'TRIP',
#   'TRVG',
#   'TTEC',
#   'TWKS',
#   'TZOO',
#   'VRA',
#   'WEST',
#   'WIMI',
#   'XP',
#   'XWEL',
#   'YTRA'},
#  'communication': {'ACIW',
#   'ADD',
#   'ADI',
#   'ADSE',
#   'ADTN',
#   'AEI',
#   'AEY',
#   'ALKT',
#   'ALTR',
#   'AMNB',
#   'AMPG',
#   'AMRK',
#   'AOSL',
#   'ARLP',
#   'ATEX',
#   'AVNW',
#   'AXNX',
#   'AXTI',
#   'AYRO',
#   'BAND',
#   'BANF',
#   'BCBP',
#   'BIDU',
#   'BNMV',
#   'BOXL',
#   'BTAI',
#   'BWMN',
#   'CASA',
#   'CCB',
#   'CCOI',
#   'CDNS',
#   'CDW',
#   'CERT',
#   'CFLT',
#   'CG',
#   'CHTR',
#   'CMTL',
#   'CNSL',
#   'CNXC',
#   'CNXN',
#   'COMM',
#   'COMS',
#   'CPOP',
#   'CPSI',
#   'CRAI',
#   'CRNT',
#   'CSCO',
#   'CSGS',
#   'CTBI',
#   'CTSH',
#   'CVCO',
#   'CVLY',
#   'CXDO',
#   'CZFS',
#   'DATS',
#   'DCOM',
#   'DCOMP',
#   'DGII',
#   'DIOD',
#   'DLPN',
#   'DOX',
#   'DRS',
#   'EBON',
#   'EGHT',
#   'EJH',
#   'EMKR',
#   'ERIC',
#   'ESLT',
#   'ESSA',
#   'EVBG',
#   'FCBC',
#   'FCEL',
#   'FLEX',
#   'FLUX',
#   'FNCB',
#   'FNGR',
#   'FRME',
#   'FUTU',
#   'FYBR',
#   'GAIA',
#   'GECC',
#   'GILT',
#   'GLAD',
#   'GNSS',
#   'HCTI',
#   'HHS',
#   'HON',
#   'HTBK',
#   'HTLF',
#   'HURN',
#   'IAC',
#   'IBEX',
#   'ICFI',
#   'IDCC',
#   'IDXX',
#   'IESC',
#   'IMMR',
#   'IMOS',
#   'INFN',
#   'INTC',
#   'IPGP',
#   'IQ',
#   'IRDM',
#   'ISUN',
#   'IVDA',
#   'JAMF',
#   'JD',
#   'JKHY',
#   'KFRC',
#   'KLTR',
#   'KTOS',
#   'LBRDA',
#   'LBRDK',
#   'LBTYA',
#   'LBTYK',
#   'LEGH',
#   'LGMK',
#   'LILA',
#   'LILAK',
#   'LITE',
#   'LIZI',
#   'LMFA',
#   'LSCC',
#   'LWLG',
#   'MCHP',
#   'MCHX',
#   'MDB',
#   'MDRX',
#   'META',
#   'MGIC',
#   'MGRC',
#   'MMAT',
#   'MNDO',
#   'MOB',
#   'MOBQ',
#   'MPWR',
#   'MTEK',
#   'MTLS',
#   'MXL',
#   'NATI',
#   'NCNO',
#   'NCTY',
#   'NECB',
#   'NICE',
#   'NRIM',
#   'NSSC',
#   'NVOS',
#   'NXGN',
#   'NXPI',
#   'NXPL',
#   'NXST',
#   'OCFC',
#   'OLK',
#   'ONB',
#   'ONBPO',
#   'ONBPP',
#   'OSBC',
#   'OSUR',
#   'OTEX',
#   'OTRK',
#   'PACW',
#   'PACWP',
#   'PALT',
#   'PAYS',
#   'PAYX',
#   'PCTI',
#   'PCTY',
#   'PEGA',
#   'PETQ',
#   'PLPC',
#   'PLXS',
#   'PMTS',
#   'POWI',
#   'POWL',
#   'QCOM',
#   'RADI',
#   'RBBN',
#   'RCRT',
#   'RDVT',
#   'RFIL',
#   'RILY',
#   'RILYP',
#   'RNST',
#   'RTC',
#   'RUM',
#   'SANM',
#   'SASR',
#   'SATS',
#   'SBAC',
#   'SBT',
#   'SCKT',
#   'SCSC',
#   'SEDG',
#   'SHEN',
#   'SITM',
#   'SMTC',
#   'SNCR',
#   'SONM',
#   'SPOK',
#   'SPT',
#   'SRCL',
#   'SSBK',
#   'SSP',
#   'SSTI',
#   'SSYS',
#   'STCN',
#   'STGW',
#   'SY',
#   'SYNH',
#   'SYTA',
#   'TAOP',
#   'TARS',
#   'TCPC',
#   'TER',
#   'TH',
#   'TIGR',
#   'TLS',
#   'TMUS',
#   'TRUE',
#   'TSAT',
#   'TSEM',
#   'TTEC',
#   'TTMI',
#   'TXN',
#   'UBFO',
#   'UBSI',
#   'UCBI',
#   'UCBIO',
#   'ULBI',
#   'UNIT',
#   'UONE',
#   'UONEK',
#   'UPWK',
#   'VERX',
#   'VIAV',
#   'VISL',
#   'VNET',
#   'VOD',
#   'VSAT',
#   'WSBC',
#   'WSBCP',
#   'WSBF',
#   'WTBA',
#   'WTFC',
#   'WTFCM',
#   'WTFCP',
#   'WTW',
#   'XRX',
#   'YY',
#   'ZBRA',
#   'ZENV',
#   'ZLAB',
#   'ZM',
#   'ZS'},
#  'materials': {'ACLS',
#   'ACMR',
#   'ADEA',
#   'ADN',
#   'AEHR',
#   'AEIS',
#   'AIHS',
#   'AIP',
#   'ALCO',
#   'ALPP',
#   'AMAT',
#   'AMBA',
#   'AMD',
#   'AMKR',
#   'AMLI',
#   'AMRK',
#   'AMSWA',
#   'ANSS',
#   'ANY',
#   'AOSL',
#   'APDN',
#   'APOG',
#   'APPN',
#   'AQMS',
#   'ARBE',
#   'ARBK',
#   'ARCB',
#   'AREC',
#   'ARLP',
#   'ASML',
#   'ASPI',
#   'ASTE',
#   'ASTL',
#   'ATLX',
#   'ATOM',
#   'AVGO',
#   'AVT',
#   'AXTI',
#   'AZ',
#   'AZPN',
#   'BECN',
#   'BITF',
#   'BLFS',
#   'BOOM',
#   'BRKR',
#   'BTBT',
#   'BTOG',
#   'BWEN',
#   'CAN',
#   'CDXC',
#   'CECO',
#   'CEVA',
#   'CG',
#   'CGNX',
#   'CHX',
#   'CIFR',
#   'CLEU',
#   'CLSK',
#   'CMBM',
#   'CMCO',
#   'CMPO',
#   'CMPR',
#   'COHU',
#   'COMM',
#   'CPSH',
#   'CRCT',
#   'CREG',
#   'CRUS',
#   'CSWC',
#   'CSWI',
#   'CSX',
#   'CWST',
#   'CYRX',
#   'DALN',
#   'DIOD',
#   'DSKE',
#   'DXPE',
#   'EBON',
#   'ELBM',
#   'ENTG',
#   'EXPO',
#   'FAST',
#   'FCBC',
#   'FEAM',
#   'FORM',
#   'FRPH',
#   'FSTR',
#   'FTHM',
#   'GFS',
#   'GIFI',
#   'GLBS',
#   'GLG',
#   'GRIN',
#   'GSM',
#   'GT',
#   'GURE',
#   'GWAV',
#   'HIMX',
#   'HON',
#   'HSIC',
#   'HTCR',
#   'HUDI',
#   'HURC',
#   'HUT',
#   'HYMC',
#   'ICHR',
#   'IDAI',
#   'IDXX',
#   'IESC',
#   'INDI',
#   'IOSP',
#   'IPGP',
#   'IREN',
#   'JBHT',
#   'JEWL',
#   'KALU',
#   'KLAC',
#   'KLIC',
#   'KRMD',
#   'KTCC',
#   'LAKE',
#   'LASE',
#   'LASR',
#   'LFCR',
#   'LFUS',
#   'LGND',
#   'LGO',
#   'LITE',
#   'LKQ',
#   'LMB',
#   'LRCX',
#   'LSCC',
#   'LWLG',
#   'MASS',
#   'MATH',
#   'MCHP',
#   'METC',
#   'METX',
#   'MFIC',
#   'MGRC',
#   'MIDD',
#   'MIGI',
#   'MKSI',
#   'MMAT',
#   'MOXC',
#   'MRVL',
#   'MU',
#   'MVST',
#   'MYRG',
#   'NATI',
#   'NCTY',
#   'NDSN',
#   'NMFC',
#   'NNBR',
#   'NNDM',
#   'NNOX',
#   'NUVA',
#   'NVDA',
#   'NVMI',
#   'NVTS',
#   'NVX',
#   'NWPX',
#   'NXPI',
#   'OFLX',
#   'OLB',
#   'OLED',
#   'ON',
#   'ONDS',
#   'ORGN',
#   'ORLY',
#   'OTTR',
#   'OXSQ',
#   'PATK',
#   'PDCO',
#   'PDFS',
#   'PHUN',
#   'PLAB',
#   'PMTS',
#   'POET',
#   'POOL',
#   'POWL',
#   'PRSO',
#   'PSEC',
#   'PTEN',
#   'PWFL',
#   'PYR',
#   'QRHC',
#   'QUIK',
#   'RAIL',
#   'RCON',
#   'REYN',
#   'RGLD',
#   'RIOT',
#   'RMBS',
#   'ROAD',
#   'ROCK',
#   'SAI',
#   'SANM',
#   'SASI',
#   'SBLK',
#   'SCHL',
#   'SCHN',
#   'SCSC',
#   'SDGR',
#   'SDIG',
#   'SGBX',
#   'SGLY',
#   'SIDU',
#   'SINT',
#   'SKYT',
#   'SLAB',
#   'SLNG',
#   'SLNH',
#   'SMTC',
#   'SSRM',
#   'SSYS',
#   'STCN',
#   'STEP',
#   'STLD',
#   'SWKS',
#   'SYNA',
#   'SYPR',
#   'TER',
#   'TGAN',
#   'TMC',
#   'TMPO',
#   'TOMZ',
#   'TRIB',
#   'TSAT',
#   'TSEM',
#   'TUSK',
#   'TXN',
#   'UCTT',
#   'UFPI',
#   'ULH',
#   'USAP',
#   'USAU',
#   'VECO',
#   'VIRC',
#   'VJET',
#   'VNET',
#   'VOXR',
#   'VTNR',
#   'VVPR',
#   'WATT',
#   'WEYS',
#   'WIMI',
#   'WULF',
#   'XMTR',
#   'XRAY',
#   'ZEUS',
#   'ZKIN'},
#  'food': {'ACTG',
#   'AGYS',
#   'AHG',
#   'ALGT',
#   'ALTO',
#   'AMSWA',
#   'ARCB',
#   'ARCC',
#   'AUVI',
#   'AVO',
#   'AYRO',
#   'BBSI',
#   'BCPC',
#   'BFI',
#   'BJRI',
#   'BLNK',
#   'BMRA',
#   'BON',
#   'BSFC',
#   'BTOG',
#   'BWMX',
#   'BYND',
#   'BZFD',
#   'BZUN',
#   'CAKE',
#   'CASY',
#   'CBRL',
#   'CENT',
#   'CENTA',
#   'CG',
#   'CGBD',
#   'CGNX',
#   'CHRW',
#   'CHSCM',
#   'CHSCP',
#   'CMCO',
#   'CNEY',
#   'COCO',
#   'COKE',
#   'COST',
#   'CSWC',
#   'CSX',
#   'CTIB',
#   'CTRN',
#   'CVGW',
#   'DGII',
#   'DLTR',
#   'DXPE',
#   'EM',
#   'EXPO',
#   'FAMI',
#   'FARM',
#   'FCEL',
#   'FDUS',
#   'FLGC',
#   'FREE',
#   'FRGI',
#   'FWRG',
#   'GAIA',
#   'GBDC',
#   'GDEN',
#   'GHSI',
#   'GO',
#   'GRVY',
#   'GURE',
#   'HAIN',
#   'HCSG',
#   'HELE',
#   'HFFG',
#   'HFWA',
#   'HTLD',
#   'HUDI',
#   'HWKN',
#   'IAC',
#   'IEP',
#   'IMKTA',
#   'JACK',
#   'JBHT',
#   'JCSE',
#   'JD',
#   'JFBR',
#   'JJSF',
#   'JWEL',
#   'KALU',
#   'KDP',
#   'KHC',
#   'KRT',
#   'KRUS',
#   'LANC',
#   'LFCR',
#   'LFMD',
#   'LIQT',
#   'LKFN',
#   'LNT',
#   'LOCO',
#   'LOOP',
#   'MANH',
#   'MDLZ',
#   'MF',
#   'MFIC',
#   'MIDD',
#   'MLCO',
#   'MLEC',
#   'MNST',
#   'MRTN',
#   'NATH',
#   'NEOG',
#   'NEPT',
#   'NWL',
#   'OCSL',
#   'OLLI',
#   'OMAB',
#   'OPK',
#   'PCTY',
#   'PDD',
#   'PETS',
#   'PETZ',
#   'PI',
#   'PPC',
#   'PSEC',
#   'PTLO',
#   'PTMN',
#   'PTVE',
#   'PWFL',
#   'PZZA',
#   'QH',
#   'QRHC',
#   'RAVE',
#   'REBN',
#   'REG',
#   'REVB',
#   'REYN',
#   'RGF',
#   'RIBT',
#   'RICK',
#   'RKDA',
#   'ROCK',
#   'RRGB',
#   'RYAAY',
#   'SAFT',
#   'SBUX',
#   'SCWO',
#   'SECO',
#   'SENEA',
#   'SGC',
#   'SHC',
#   'SIRI',
#   'SMPL',
#   'SNAX',
#   'SOPA',
#   'SOVO',
#   'SPTN',
#   'STBX',
#   'STEP',
#   'STKH',
#   'STKL',
#   'STKS',
#   'SVFD',
#   'TASK',
#   'TCPC',
#   'TH',
#   'TIO',
#   'TITN',
#   'TKLF',
#   'TLRY',
#   'TOMZ',
#   'TRIP',
#   'TXRH',
#   'TZOO',
#   'UGRO',
#   'ULH',
#   'URBN',
#   'VEDU',
#   'VFF',
#   'VIOT',
#   'VITL',
#   'VLGEA',
#   'WBD',
#   'WEN',
#   'WERN',
#   'WEST',
#   'WING',
#   'WNW',
#   'WTER',
#   'WW',
#   'WYNN',
#   'YJ',
#   'YORW',
#   'YOSH',
#   'ZEUS',
#   'ZIVO',
#   'ZKIN'},
#  'ad': {'ADBE',
#   'ADTH',
#   'ADV',
#   'ALAR',
#   'AMZN',
#   'ANGI',
#   'APP',
#   'APPS',
#   'ARCE',
#   'ATVI',
#   'BEEM',
#   'BIDU',
#   'BKNG',
#   'BZFD',
#   'CCOI',
#   'CDLX',
#   'CHTR',
#   'CMCSA',
#   'CMPR',
#   'CNET',
#   'CNSL',
#   'CPOP',
#   'CURI',
#   'DALN',
#   'DLO',
#   'DRCT',
#   'DSP',
#   'EEFT',
#   'EGHT',
#   'EHTH',
#   'ERIC',
#   'ERIE',
#   'ETSY',
#   'EVGO',
#   'EXPE',
#   'FAZE',
#   'FFIN',
#   'FOX',
#   'FOXA',
#   'GAME',
#   'GSMG',
#   'HEPS',
#   'IAS',
#   'IHRT',
#   'IQ',
#   'JG',
#   'JZ',
#   'KBNT',
#   'KC',
#   'KRKR',
#   'LAMR',
#   'LBRDA',
#   'LBRDK',
#   'LEE',
#   'LFLY',
#   'LVO',
#   'MDGS',
#   'MELI',
#   'MFIC',
#   'MGNI',
#   'MLGO',
#   'MOBQ',
#   'MOMO',
#   'MRIN',
#   'MSFT',
#   'NCMI',
#   'NWS',
#   'NWSA',
#   'NXST',
#   'NXTP',
#   'OB',
#   'OCSL',
#   'ONFO',
#   'OPRA',
#   'OSTK',
#   'PERI',
#   'PETS',
#   'PUBM',
#   'RCRT',
#   'RDVT',
#   'ROKU',
#   'RUM',
#   'SALM',
#   'SCOR',
#   'SLGG',
#   'SRAD',
#   'STBX',
#   'STGW',
#   'STRA',
#   'SWBI',
#   'SYNH',
#   'TAOP',
#   'TCOM',
#   'THRY',
#   'TOUR',
#   'TRKA',
#   'TRMR',
#   'TTD',
#   'TTGT',
#   'UCL',
#   'UK',
#   'VERI',
#   'VS',
#   'WB',
#   'WIMI',
#   'XNET',
#   'Z',
#   'ZG'},
#  'sport': {'ADD',
#   'AMBA',
#   'ANIK',
#   'AOUT',
#   'APPS',
#   'ASO',
#   'BACK',
#   'BBLG',
#   'BGFV',
#   'BRAG',
#   'BVS',
#   'BZFD',
#   'CASY',
#   'CHDN',
#   'CHTR',
#   'CLAR',
#   'CMCSA',
#   'CMLS',
#   'CNXA',
#   'COKE',
#   'CPOP',
#   'CTRN',
#   'CZR',
#   'DISH',
#   'DKNG',
#   'DYNT',
#   'EA',
#   'ELYS',
#   'ERIC',
#   'FIVE',
#   'FOX',
#   'FOXA',
#   'FUV',
#   'GAMB',
#   'GAN',
#   'GIII',
#   'GMGI',
#   'GNTX',
#   'HAS',
#   'HELE',
#   'HEPS',
#   'HIBB',
#   'HOFV',
#   'IHRT',
#   'INSE',
#   'JAKK',
#   'JJSF',
#   'JRSH',
#   'KALU',
#   'KIDS',
#   'LBRDA',
#   'LBRDK',
#   'LBTYA',
#   'LBTYK',
#   'LMB',
#   'LSXMA',
#   'LSXMK',
#   'MCFT',
#   'MDXG',
#   'MNST',
#   'MVLA',
#   'NATR',
#   'NEGG',
#   'NIU',
#   'NTES',
#   'NVOS',
#   'NWS',
#   'NWSA',
#   'ORGO',
#   'PARA',
#   'PARAA',
#   'PARAP',
#   'PDD',
#   'PENN',
#   'PHUN',
#   'PI',
#   'PLAY',
#   'POWW',
#   'RICK',
#   'RIVN',
#   'ROKU',
#   'SBET',
#   'SBGI',
#   'SEAT',
#   'SIRI',
#   'SMFL',
#   'SP',
#   'SPWH',
#   'SRAD',
#   'STBX',
#   'THRN',
#   'TSAT',
#   'TSLA',
#   'TTWO',
#   'VCEL',
#   'VERB',
#   'VISL',
#   'WDFC',
#   'WINA',
#   'WTER',
#   'WYNN'},
#  'entertainment': {'ADD',
#   'ADSK',
#   'AGAE',
#   'AHG',
#   'AMCX',
#   'ANGH',
#   'API',
#   'ATVI',
#   'BASE',
#   'BHAT',
#   'BIDU',
#   'BILI',
#   'BSQR',
#   'BZFD',
#   'CD',
#   'CG',
#   'CHDN',
#   'CHTR',
#   'CMCO',
#   'CMLS',
#   'CNSL',
#   'CNVS',
#   'COMM',
#   'CPOP',
#   'CRAI',
#   'CRUS',
#   'CSSE',
#   'CSSEP',
#   'CTLP',
#   'CTSH',
#   'CURI',
#   'CZR',
#   'DGLY',
#   'DKNG',
#   'DLPN',
#   'DOX',
#   'DOYU',
#   'EGLX',
#   'EM',
#   'ENSG',
#   'EVBG',
#   'FLNT',
#   'FNKO',
#   'FOX',
#   'FOXA',
#   'GAME',
#   'GDEN',
#   'GMBL',
#   'GROM',
#   'GRVY',
#   'GSMG',
#   'HAS',
#   'HEAR',
#   'HOFT',
#   'HOFV',
#   'IAC',
#   'IBEX',
#   'IHRT',
#   'INSE',
#   'IQ',
#   'JAKK',
#   'JG',
#   'KC',
#   'KRKR',
#   'LBRDA',
#   'LBRDK',
#   'LBTYA',
#   'LBTYK',
#   'LEDS',
#   'LILA',
#   'LILAK',
#   'LIZI',
#   'LMB',
#   'LSXMA',
#   'LSXMK',
#   'MAT',
#   'MLCO',
#   'MMV',
#   'MOMO',
#   'MVLA',
#   'NCMI',
#   'NEGG',
#   'NFLX',
#   'NMFC',
#   'NTAP',
#   'NWS',
#   'NWSA',
#   'PARA',
#   'PARAA',
#   'PARAP',
#   'PENN',
#   'PLAY',
#   'PLBY',
#   'ROKU',
#   'RPD',
#   'RRR',
#   'SGC',
#   'SIRI',
#   'SNPO',
#   'SRAD',
#   'SSP',
#   'STER',
#   'SWKS',
#   'TTEC',
#   'TTWO',
#   'TZOO',
#   'UEIC',
#   'UONE',
#   'UONEK',
#   'VERI',
#   'VISL',
#   'VNET',
#   'VSAT',
#   'WBD',
#   'WIMI',
#   'WISA',
#   'WMG',
#   'ZD',
#   'ZFOX'},
#  'water': {'ADES',
#   'ALPP',
#   'ALRM',
#   'ARTNA',
#   'AY',
#   'BAER',
#   'BRY',
#   'BWMN',
#   'BWV',
#   'CASY',
#   'CCEP',
#   'CDZI',
#   'CECO',
#   'CENT',
#   'CENTA',
#   'CHX',
#   'CINF',
#   'CNEY',
#   'COCO',
#   'COKE',
#   'COLM',
#   'CTIB',
#   'CWCO',
#   'DOGZ',
#   'EJH',
#   'ERII',
#   'ESOA',
#   'FANG',
#   'FCEL',
#   'FELE',
#   'FIZZ',
#   'FSTR',
#   'FTDR',
#   'GEOS',
#   'GURE',
#   'GWRS',
#   'HELE',
#   'HEPS',
#   'HFFG',
#   'HWKN',
#   'HYFM',
#   'ICUI',
#   'IDXX',
#   'IMKTA',
#   'IPW',
#   'ITRI',
#   'KDP',
#   'LANDO',
#   'LASE',
#   'LIQT',
#   'LOOP',
#   'MCFT',
#   'MIDD',
#   'MNST',
#   'MSEX',
#   'NEOG',
#   'NWPX',
#   'NXGL',
#   'OM',
#   'ORLY',
#   'OTTR',
#   'PEP',
#   'QRHC',
#   'RCON',
#   'RIOT',
#   'RKDA',
#   'ROP',
#   'RPID',
#   'SCWO',
#   'SDC',
#   'STRL',
#   'TRMB',
#   'TTEK',
#   'TUSK',
#   'UCTT',
#   'UGRO',
#   'USLM',
#   'VEEE',
#   'VIOT',
#   'WTER',
#   'WYNN',
#   'YORW',
#   'ZKIN'},
#  'security': {'ADSE',
#   'ALAR',
#   'ALLT',
#   'ALRM',
#   'AMBA',
#   'AOUT',
#   'APDN',
#   'AREB',
#   'ATLO',
#   'AZ',
#   'BEEM',
#   'BHF',
#   'BHFAM',
#   'BHFAN',
#   'BHFAO',
#   'BHFAP',
#   'BLZE',
#   'BYRN',
#   'CARE',
#   'CDW',
#   'CGNT',
#   'CHKP',
#   'CHTR',
#   'CISO',
#   'CLBT',
#   'CMPO',
#   'COMM',
#   'COMS',
#   'CRWD',
#   'CSCO',
#   'CTLP',
#   'CVLT',
#   'DDOG',
#   'DGLY',
#   'DPRO',
#   'DSKE',
#   'DTSS',
#   'DTST',
#   'EGIO',
#   'ERIC',
#   'ESLT',
#   'EVBG',
#   'EVLV',
#   'EXPD',
#   'FA',
#   'FBMS',
#   'FFIV',
#   'FLIC',
#   'FORA',
#   'FORR',
#   'FRHC',
#   'FROG',
#   'FSV',
#   'FTNT',
#   'FWRD',
#   'GDS',
#   'GEN',
#   'GEOS',
#   'GFAI',
#   'GILT',
#   'GNTX',
#   'GRRR',
#   'HCP',
#   'HIMX',
#   'HUBC',
#   'ICFI',
#   'IDAI',
#   'IDN',
#   'INPX',
#   'INTZ',
#   'INVE',
#   'JAMF',
#   'JKHY',
#   'KFRC',
#   'KLTR',
#   'KSCP',
#   'KTOS',
#   'LBRDA',
#   'LBRDK',
#   'LBTYA',
#   'LBTYK',
#   'LGMK',
#   'LIZI',
#   'MCHP',
#   'MIND',
#   'MINM',
#   'MMAT',
#   'MOBQ',
#   'MSFT',
#   'MSTR',
#   'MTEK',
#   'MXL',
#   'NMFC',
#   'NSSC',
#   'NTCT',
#   'NTGR',
#   'NTNX',
#   'NWL',
#   'NXPI',
#   'OKTA',
#   'OMAB',
#   'ONDS',
#   'OSIS',
#   'OSPN',
#   'OTEX',
#   'PANW',
#   'PAYO',
#   'PAYX',
#   'PFIS',
#   'PMTS',
#   'PRCH',
#   'PRGS',
#   'PRST',
#   'PUBM',
#   'PWFL',
#   'RDVT',
#   'RDWR',
#   'RGP',
#   'RMBS',
#   'RMNI',
#   'RPD',
#   'RXT',
#   'SCSC',
#   'SCWX',
#   'SIFY',
#   'SIRI',
#   'SLAB',
#   'SMCI',
#   'SNPS',
#   'SNT',
#   'SP',
#   'SPCB',
#   'SPLK',
#   'STER',
#   'SWBI',
#   'SYTA',
#   'TASK',
#   'TCOM',
#   'TEAM',
#   'TENB',
#   'TH',
#   'TIGO',
#   'TLS',
#   'TOWN',
#   'TTGT',
#   'UBFO',
#   'UBSI',
#   'UEIC',
#   'VIAV',
#   'VIEW',
#   'VNET',
#   'VOD',
#   'VREX',
#   'VRNS',
#   'VRSN',
#   'WKEY',
#   'WRAP',
#   'XP',
#   'ZS'},
#  'mining': {'ALCO',
#   'ALPP',
#   'AMLI',
#   'ANY',
#   'APPN',
#   'ARBK',
#   'ARLP',
#   'ATLX',
#   'AZPN',
#   'BITF',
#   'BTBT',
#   'BTOG',
#   'BWEN',
#   'CAN',
#   'CG',
#   'CHX',
#   'CIFR',
#   'CLSK',
#   'CMBM',
#   'CMCO',
#   'CSWI',
#   'DSKE',
#   'DXPE',
#   'EBON',
#   'FAST',
#   'FCBC',
#   'FRPH',
#   'FTHM',
#   'GRIN',
#   'GT',
#   'HTCR',
#   'HUT',
#   'HYMC',
#   'IDAI',
#   'IREN',
#   'LFUS',
#   'MATH',
#   'METX',
#   'MIGI',
#   'MOXC',
#   'MVST',
#   'MYRG',
#   'NCTY',
#   'NNOX',
#   'NVDA',
#   'OLB',
#   'ONDS',
#   'PHUN',
#   'POWL',
#   'PTEN',
#   'PWFL',
#   'PYR',
#   'RCON',
#   'RIOT',
#   'ROAD',
#   'SAI',
#   'SDIG',
#   'SLNG',
#   'SLNH',
#   'SSRM',
#   'TSAT',
#   'TUSK',
#   'USAU',
#   'VOXR',
#   'VVPR',
#   'WULF',
#   'ZEUS'},
#  'optic': {'ANGO',
#   'AOUT',
#   'AXTI',
#   'BIOL',
#   'CLPT',
#   'CUTR',
#   'ESLT',
#   'FARO',
#   'IPGP',
#   'IRIX',
#   'KLAC',
#   'LASE',
#   'LASR',
#   'LAZR',
#   'LITE',
#   'LNSR',
#   'LPTH',
#   'MATW',
#   'MKSI',
#   'MMAT',
#   'MRVL',
#   'MVIS',
#   'NOVT',
#   'OSIS',
#   'SASI',
#   'SRTS',
#   'SY',
#   'VECO',
#   'XMTR',
#   'ZEUS'}}

# %%
# 각 회사 별 theme 정보
theme_from_cp = {}

for n in range(len(df_na_drop)):
    name = df_na_drop.iloc[n]['tck_iem_cd']
    theme_from_cp[name] = []
    for k in cp_from_theme.keys():
        if name in cp_from_theme[k]:
            theme_from_cp[name].append(k)
        
theme_from_cp['NVDA']
# Out:
# ['network', 'data', 'game', 'device', 'vehicle', 'ai', 'materials', 'mining']

# %%
df_na = df.isnull()
df_na.iloc[349]['description'] == True
# Out:
# True

# %%
# 원하는 단어를 바탕으로 관련 회사 추출 코드
# item_list에 원하는 단어를 key에 그 단어와 관련 또는 지칭하는 단어들을 value에 넣어준 뒤 돌리면 된다. 그리고 word에는 탐색 원하는 key setting.
word = 'gpu'
wt = ['gpu', 'gpus', 'tpus', 'tpu']
# word = 'ai'
# wt = ['ai', 'artificial', 'intelligence', 'a.i', 'a.i.']
nan_company = {}
rising_cp = []
item_list = {'computers' : ['computer', 'computers'], 'game' : ['gaming'], 'ai':['AI', 'ai']}
item_list[word] = wt
for i in range(len(df_na_drop)):
    lst = df_na_drop.iloc[i]['description'].replace(",", '')
    lst = lst.lower()
    lst = lst.replace('.', '')
    lst = lst.split(" ")
    
    for wrd in item_list[word]:
        if wrd in lst:
            rising_cp.append(df_na_drop.iloc[i]['tck_iem_cd'])

cp = set(rising_cp)
cp
# Out:
# {'NVDA', 'SGH'}

# %%
b = df['description'][df['tck_iem_cd']=='API']
df.iloc[187]['description']
# Out:
# "Agora, Inc. provides real-time engagement platform-as-a-service (RTE-PaaS) in the People's Republic of China, the United States, and internationally. The company's RTE-PaaS offers developers with software tools to embed real-time voice, video, interactive live-streaming, chat, whiteboard, and artificial intelligence functionalities. Its products include video calling, voice calling, interactive live streaming, chat, and signaling; and extensions, which comprise interactive whiteboard, recording, 3D spatial audio, AI noise suppression, analytics, and extensions marketplace products to enable developers to launch RTE in specific use cases. The company also provides Flexible Classroom that offers a low-code application platform as a service; and App Builder, a no-code application platform. Its real-time engagement products are delivered through its software-defined real-time network, which is a virtual network overlay on top of the public internet. The company serves social, entertainment, gaming, education, enterprise solutions, e-commerce, financial services, healthcare, and IoT industries. Agora, Inc. was incorporated in 2013 and is based in Shanghai, the People's Republic of China."

# %%
rising_cp # oil, smartphone,
# Out:
# ['ACDC',
#  'ALTO',
#  'AMTX',
#  'ARCC',
#  'ARLP',
#  'ASTE',
#  'AZPN',
#  'BKR',
#  'BOOM',
#  'BRY',
#  'BWEN',
#  'CG',
#  'CHSCM',
#  'CHSCP',
#  'CHX',
#  'CLMT',
#  'CLVR',
#  'CMTL',
#  'COCO',
#  'CPLP',
#  'CPSH',
#  'CREG',
#  'CRNT',
#  'CSWC',
#  'CTRM',
#  'CZFS',
#  'DMLP',
#  'DRVN',
#  'DXPE',
#  'EPSN',
#  'EVRG',
#  'FANG',
#  'FAST',
#  'FELE',
#  'FFIN',
#  'FIP',
#  'FSTR',
#  'GEOS',
#  'GRIN',
#  'GURE',
#  'HAYN',
#  'HCCI',
#  'HPK',
#  'HTOO',
#  'HUDI',
#  'IMPP',
#  'IOSP',
#  'IPGP',
#  'KLXE',
#  'LKQ',
#  'MARPS',
#  'MFIC',
#  'MMLP',
#  'MTRX',
#  'NWPX',
#  'ORLY',
#  'PAA',
#  'PAGP',
#  'PCTI',
#  'PNRG',
#  'POWL',
#  'PSEC',
#  'PTEN',
#  'PYR',
#  'QRHC',
#  'RCON',
#  'SANM',
#  'SASI',
#  'SCWO',
#  'SND',
#  'SNT',
#  'SYPR',
#  'TCPC',
#  'TKLF',
#  'TRMD',
#  'TSAT',
#  'TUSK',
#  'USAP',
#  'USEG',
#  'USLM',
#  'YTEN',
#  'ZKIN']
